# %% [markdown]
# # Download GEDI data for ROI
#
# 1. Request Metadata for granules overlapping ROI
# 2. Download appropriate h5 files
# 3. Upload data into PostGIS

# %%
# Autoreload source modules
# To immediately pick up code changes in src/
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from geopandas import gpd
import datetime as dt
from shapely.geometry import box

from src.data.gedi_cmr_query import query
from src.data.gedi_database_loader import bulk_import_from_directory
from src.constants import USER_PATH, GEDI_L2A_PATH, GEDI_L4A_PATH

# %% [markdown]
# ## 1. Request Metadata for granules overlapping ROI

# %%
shapefile = USER_PATH / "Amazon_rainforest_shapefile.zip"
shp = gpd.read_file(shapefile)
# The CMR API cannot accept a shapefile with more than 5000 points,
# so we simplify our query to just the bounding box around the region.
poly = gpd.GeoSeries(box(*shp.geometry.values[0].bounds))
print(shp.geometry.values[0].bounds)

### Plot the spatial query area and bounding box using geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
base = world.plot(color='white', edgecolor='black', figsize  = (7, 7))
poly.plot(ax=base, color='white', edgecolor='red', alpha=0.5)
shp.plot(ax=base, color='white', edgecolor='green', alpha=0.5)
# Out:
# (-79.43629454418107, -18.00816774555682, -44.49108551883751, 8.663468955080305)
# <AxesSubplot:>

# %%
gdf = query(
    product="gedi_l2a", 
    spatial=poly,
)

gdf_l4a = query(
    product="gedi_l4a",
    spatial=poly
)

# %%
print ("Total granules found: ", len(gdf.index)-1)
print ("Total file size (MB): ", gdf['granule_size'].sum())
print ("Total granules found: ", len(gdf_l4a.index)-1)
print ("Total file size (MB): ", gdf_l4a['granule_size'].sum())

print(gdf.granule_name.head(5))
print(gdf_l4a.granule_name.head(5))
# Out:
# Total granules found:  5580
# Total file size (MB):  8913069.4487
# Total granules found:  2026
# Total file size (MB):  1836951.863917
# 0    GEDI02_A_2019108080339_O01964_01_T05337_02_003...
# 1    GEDI02_A_2019108093620_O01965_02_T05338_02_003...
# 2    GEDI02_A_2019108093620_O01965_01_T05338_02_003...
# 3    GEDI02_A_2019108110901_O01966_02_T02493_02_003...
# 4    GEDI02_A_2019109193528_O01987_04_T00632_02_003...
# Name: granule_name, dtype: object
# 17    GEDI04_A_2019110075658_O01995_T02063_02_001_01.h5
# 18    GEDI04_A_2019110092939_O01996_T03334_02_001_01.h5
# 19    GEDI04_A_2019110184547_O02002_T01917_02_001_01.h5
# 20    GEDI04_A_2019110201828_O02003_T01918_02_001_01.h5
# 21    GEDI04_A_2019110215109_O02004_T03189_02_001_01.h5
# Name: granule_name, dtype: object

# %%
gdf.to_csv(GEDI_L2A_PATH / 'l2a_granules_long.txt', columns = ['granule_name', 'granule_url'], index=False, header = False, sep=' ')
gdf_l4a.to_csv(GEDI_L4A_PATH / 'l4a_granules_long.txt', columns = ['granule_name', 'granule_url'], index=False, header = False, sep=' ')

# %% [markdown]
# ## 2. Download h5 files
#
# To download the files automatically, enter the directory into which the data files should be downloaded and run
#
# ```
# $ nohup $USER_PATH/scripts/download_files.sh <granule_list_file_name> &
# ```
#
# This script will download the files in parallel in the background. If it is your first time running the script, it will ask for your Earthdata username and password to log in to the NASA Earthdata portal.
#
# The script is idempotent, so it can be stopped and restarted at any time. Log messages are saved to `nohup.out`.
#
# Partial downloads are saved in ".part" files, so after the script completes you can check for failed downloads with
#
# ```
# $ ls | grep .part
# ```
#
# Rerunning the download_files.sh script will clean up and reattempt all failed downloads.

# %% [markdown]
# ## 3. Upload data to PostGIS

# %% [markdown]
# Create a PostGIS database with an appropriate schema.
#
# Remove all constraints (e.g. UNIQUE, INDEX, etc.) before beginning upload. You will restore them to the table at the end.

# %% [markdown]
# ```
#     $ nohup python3 scratch/run_db_load_4a.py &
# ```

# %%
checkpoint_file = GEDI_L4A_PATH / "bulk_import_checkpoint.txt"
roi = gpd.GeoDataFrame(shp.geometry)

bulk_import_from_directory(
    dir=GEDI_L4A_PATH, 
    roi=roi,
    table_name="level_4a", 
    checkpoint=checkpoint_file,
    restore=False,
)
# Out:
#   0%|          | 0/2027 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_330384/313453710.py in <module>
#       2 roi = gpd.GeoDataFrame(shp.geometry)
#       3
# ----> 4 bulk_import_from_directory(
#       5     dir=GEDI_L4A_PATH,
#       6     roi=roi,
#
# /home/forecol/biomass-recovery/src/data/gedi_database_loader.py in bulk_import_from_directory(dir, roi, table_name, checkpoint)
#     100
#     101     for file in tqdm(file_tracker.remaining_files):
# --> 102         gdf = _parse_file(file)
#     103         gdf = _filter_granules(gdf, roi)
#     104         _to_postgis(gdf, table_name, table, engine, check_duplicates)
#
# /home/forecol/biomass-recovery/src/data/gedi_database_loader.py in _parse_file(file)
#      52             with warnings.catch_warnings():
#      53                 warnings.simplefilter("ignore")
# ---> 54                 granule_data.append(beam.main_data)
#      55         except KeyError:
#      56             logger.warn(f"Data for beam {beam.name} in granule {file.name} incomplete")
#
# /home/forecol/biomass-recovery/src/data/gedi_granule.py in main_data(self)
#     381         if self._cached_data is None:
#     382             data = self._get_main_data_dict()
# --> 383             geometry = self.shot_geolocations
#     384             self._cached_data = gpd.GeoDataFrame(data, geometry=geometry, crs=WGS84)
#     385
#
# /home/forecol/biomass-recovery/src/data/gedi_granule.py in shot_geolocations(self)
#     343         if self._shot_geolocations is None:
#     344             if self.parent_granule.product == "GEDI_L4A":
# --> 345                 self._shot_geolocations = gpd.points_from_xy(
#     346                     x = self["lon_lowestmode"],
#     347                     y = self["lat_lowestmode"],
#
# /home/forecol/bin/miniconda3/envs/biomass/lib/python3.9/site-packages/geopandas/array.py in points_from_xy(x, y, z, crs)
#     256     output : GeometryArray
#     257     """
# --> 258     return GeometryArray(vectorized.points_from_xy(x, y, z), crs=crs)
#     259
#     260
#
# /home/forecol/bin/miniconda3/envs/biomass/lib/python3.9/site-packages/geopandas/_vectorized.py in points_from_xy(x, y, z)
#     249         return pygeos.points(x, y, z)
#     250     else:
# --> 251         out = _points_from_xy(x, y, z)
#     252         aout = np.empty(len(x), dtype=object)
#     253         with compat.ignore_shapely2_warnings():
#
# /home/forecol/bin/miniconda3/envs/biomass/lib/python3.9/site-packages/geopandas/_vectorized.py in _points_from_xy(x, y, z)
#     235         geom = [shapely.geometry.Point(i, j, k) for i, j, k in zip(x, y, z)]
#     236     else:
# --> 237         geom = [shapely.geometry.Point(i, j) for i, j in zip(x, y)]
#     238     return geom
#     239
#
# /home/forecol/bin/miniconda3/envs/biomass/lib/python3.9/site-packages/geopandas/_vectorized.py in <listcomp>(.0)
#     235         geom = [shapely.geometry.Point(i, j, k) for i, j, k in zip(x, y, z)]
#     236     else:
# --> 237         geom = [shapely.geometry.Point(i, j) for i, j in zip(x, y)]
#     238     return geom
#     239
#
# /home/forecol/bin/miniconda3/envs/biomass/lib/python3.9/site-packages/shapely/geometry/point.py in __init__(self, *args)
#      55                 )
#      56             else:
# ---> 57                 geom, n = geos_point_from_py(tuple(args))
#      58             self._set_geom(geom)
#      59             self._ndim = n
#
# /home/forecol/bin/miniconda3/envs/biomass/lib/python3.9/site-packages/shapely/geometry/point.py in geos_point_from_py(ob, update_geom, update_ndim)
#     260         coords = ob
#     261     n = len(coords)
# --> 262     dx = c_double(coords[0])
#     263     dy = c_double(coords[1])
#     264     dz = None
#
# KeyboardInterrupt:

# %%
checkpoint_file = GEDI_L2A_PATH / "bulk_import_checkpoint.txt"
bulk_import_from_directory(
    dir=GEDI_L2A_PATH, 
    roi=shp,
    table_name="level_2a", 
    checkpoint=checkpoint_file
)
