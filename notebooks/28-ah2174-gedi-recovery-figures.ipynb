# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# from tqdm.autonotebook import tqdm
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.img_tiles as cimgt
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
import pathlib
import seaborn as sns

from scipy.stats import linregress, gaussian_kde

import skgstat as skg
from pylr2 import regress2

from biomassrecovery import environment

# %% [markdown]
# ### 0. Study Area

# %%
import wradlib as wrl
from matplotlib.colors import LogNorm
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.ticker as ticker

# Colorcode the JRC classes
# UNDISTURBED = 1 -> darkgreen
# DEGRADATION = 2 -> yellow
# DEFORESTATION = 3 -> red
# RECOVERY = 4 -> greenyellow
# WATER = 5 -> blue
# OTHER_LAND_USE = 6 -> white

# We do this by assigning each color to the range v - 0.5, v + 0.5,
# where v is the value of the JRC class
colors = ['darkgreen', 'yellow', 'red', 'greenyellow', 'blue', 'white']
levels = np.arange(0.5, 6.6, 1)
cmap, norm = mpl.colors.from_levels_and_colors(list(levels), colors)

def plot_dem(filename, ax):
    ds = wrl.io.open_raster(filename)
    # pixel_spacing is in output units (lonlat)
    ds = wrl.georef.reproject_raster_dataset(ds, spacing=0.02)
    rastervalues, rastercoords, proj = wrl.georef.extract_raster_dataset(ds)
    # specify kwargs for plotting, using terrain colormap and LogNorm
    dem = ax.pcolormesh(
        rastercoords[..., 0],
        rastercoords[..., 1],
        rastervalues,
        cmap=cmap,
        norm=norm,
        transform=ccrs.PlateCarree(),
    )

# %%
from matplotlib.lines import Line2D

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_extent([-85, -40, -20, 10], crs=ccrs.PlateCarree())

# Background: Stamen terrain with added Cartopy features
# stamen_terrain = cimgt.Stamen('terrain-background')
# ax.add_image(stamen_terrain, 8)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Add the JRC raster tiles
# N.b. This takes about 35 seconds per file to plot with 0.02 degree pixels
# Increase 'spacing' for faster plotting at lower resolution
files = [ f.as_posix() for f in (environment.JRC_PATH / "AnnualChange" / "tifs").glob("*2021_SAM*_[NS][01]*.tif") ]
for f in files:
    plot_dem(f, ax)

# Add the region shapefile
shape = gpd.read_file("/home/ah2174/shapefiles/Amazon_rainforest_shapefile.zip")
shape.plot(ax=ax, color='none', edgecolor='slategrey', linewidth=3, zorder=5)

# Longitude and latitude degrees on the axes
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)
gl.xlabel_style = {'size': 15}
gl.ylabel_style = {'size': 15}

cmap = mpl.colors.ListedColormap(['darkgreen', 'yellow', 'red', 'greenyellow', 'blue', 'white'])
legend_elements = [
        Line2D([0], [0], marker='s', color='darkgreen', label="Undisturbed tropical moist forest (TMF)",
            markerfacecolor='darkgreen', markersize=10, linestyle='None'),
        Line2D([0], [0], marker='s', color='yellow', label="Degraded TMF",
            markerfacecolor='yellow', markersize=10, linestyle='None'),
        Line2D([0], [0], marker='s', color='red', label="Deforested land",
            markerfacecolor='red', markersize=10, linestyle='None'),
        Line2D([0], [0], marker='s', color='greenyellow', label="Forest regrowth",
            markerfacecolor='greenyellow', markersize=10, linestyle='None'),
        Line2D([0], [0], marker='s', color='blue', label="Permanent or seasonal water",
            markerfacecolor='blue', markersize=10, linestyle='None'),
        Line2D([0], [0], marker='s', markeredgecolor='black', label="Other land cover or no data",
            markerfacecolor='white', markersize=10, linestyle='None'),
        Line2D([0], [0], color='slategrey', linewidth=3, label="Study region"),
    ]
ax.legend(bbox_to_anchor=(1.0, 0.215), handles=legend_elements)

# %% [markdown]
# ### 1. Read in data

# %%
df = pd.read_feather('/maps/forecol/data/Overlays/monte_carlo/results/std0/master_summary_allyears.feather')

l4a_data = df
l4a_data['agcd'] = l4a_data.agbd * 0.47
l4a_data['recovery_period'] = l4a_data.mode_vals
quality_gedi = l4a_data[(l4a_data.recovery_period >= 3) & (l4a_data.recovery_period <= 22)]

# %%
quality_gedi.absolute_time.max()
# Out:
# Timestamp('2021-08-04 15:30:05.586429+0100', tz='pytz.FixedOffset(60)')

# %%
quality_gedi_gdf = gpd.GeoDataFrame(quality_gedi, geometry=gpd.points_from_xy(quality_gedi.lon_lowestmode, quality_gedi.lat_lowestmode))

# %% [markdown]
# ### 2. Basic data filtering

# %%
qg = quality_gedi

n = len(qg)
print(n)
# sample = np.random.choice(n, size=int(n/5), replace=False)
# x = qg.recovery_period.iloc[sample].values
# y = qg.agbd.iloc[sample].values

x = qg.recovery_period.values
y = qg.agcd.values

# Calculate the point density distribution per age group
ages = np.unique(x)
z = np.zeros(y.shape)
for i in ages:
    z[x == i] = gaussian_kde(y[x == i])(y[x == i])


# Sort the points by density, so that the densest points are plotted last
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

# limit to only the points with high enough density
# x = x[z > 0.005]
# y = y[z > 0.005]
# z = z[z > 0.005]

fig, ax = plt.subplots()
im = ax.scatter(x, y, c=z, s=150, cmap='PuRd')
ax.set_ylim([0,60])
ax.set_xticks(ages[::2])
ax.tick_params(axis='both', which='major', labelsize=12)
ax.set_xlabel("Recovery age (years)", size=15)
ax.set_ylabel("ACD (MgC/ha)", size=15)
plt.colorbar(im)

plt.show()
# Out:
# 29140

# %%
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_extent([-85, -40, -20, 10], crs=ccrs.PlateCarree())

# Background: Stamen terrain with added Cartopy features
stamen_terrain = cimgt.Stamen('terrain-background')
ax.add_image(stamen_terrain, 8)
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.add_feature(cfeature.RIVERS)

# Add the colorbar axes anywhere in the figure. Its position will be
# re-calculated after the main plot is drawn
cbar_ax = fig.add_axes([0, 0, 0.1, 0.1])
cbar_orientation = "horizontal"
cbar_width = 0.03

# Add the region shapefile
shape = gpd.read_file("/home/ah2174/shapefiles/Amazon_rainforest_shapefile.zip")
shape.plot(ax=ax, color='none', edgecolor='slategrey', linewidth=1, zorder=5)

# Plot our data
not_outliers = quality_gedi_gdf[(quality_gedi_gdf.agcd < 120)]
not_outliers.plot(column='agcd', zorder=10, markersize=1, ax=ax, cmap='inferno', legend=True, legend_kwds={"orientation": cbar_orientation, "label": "ACD (MgC/ha)"}, cax=cbar_ax)

## Find the location of the main plot axes now that the plot has been drawn, and stick our colorbar there.
posn = ax.get_position()
if cbar_orientation == "vertical":
    cbar_ax.set_position([posn.x0+posn.width+0.05, posn.y0, cbar_width, posn.height])
    cbar_ax.tick_params(axis="y", which="major", labelsize=15)
    cbar_ax.yaxis.label.set_size(15)
if cbar_orientation == "horizontal":
    cbar_ax.set_position([posn.x0, posn.y0-0.07, posn.width, cbar_width])
    cbar_ax.tick_params(axis="x", which="major", labelsize=15)
    cbar_ax.xaxis.label.set_size(15)

# Longitude and latitude degrees on the axes
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)
gl.xlabel_style = {'size': 15}
gl.ylabel_style = {'size': 15}

plt.show()

# %%
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_extent([-85, -40, -20, 10], crs=ccrs.PlateCarree())

# Background: Stamen terrain with added Cartopy features
stamen_terrain = cimgt.Stamen('terrain-background')
ax.add_image(stamen_terrain, 8)
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.add_feature(cfeature.RIVERS)

# Add the colorbar axes anywhere in the figure. Its position will be
# re-calculated after the main plot is drawn
cbar_ax = fig.add_axes([0, 0, 0.1, 0.1])
cbar_orientation = "horizontal"
cbar_width = 0.03

# Add the region shapefile
shape = gpd.read_file("/home/ah2174/shapefiles/Amazon_rainforest_shapefile.zip")
shape.plot(ax=ax, color='none', edgecolor='slategrey', linewidth=1, zorder=5)

# Plot our data
not_outliers = quality_gedi_gdf[quality_gedi_gdf.agcd < 120]
max_age = int(not_outliers.recovery_period.max())
not_outliers.plot(
    column='recovery_period', zorder=10, markersize=1, ax=ax, cmap='Reds', 
    legend=True, legend_kwds={
        "orientation": cbar_orientation, 
        "label": "recovery age (years)", 
        "ticks": list(range(max_age + 1))
    }, cax=cbar_ax
)

## Find the location of the main plot axes now that the plot has been drawn, and stick our colorbar there.
posn = ax.get_position()
if cbar_orientation == "vertical":
    cbar_ax.set_position([posn.x0+posn.width+0.05, posn.y0, cbar_width, posn.height])
    cbar_ax.tick_params(axis="y", which="major", labelsize=15)
    cbar_ax.yaxis.label.set_size(15)
if cbar_orientation == "horizontal":
    cbar_ax.set_position([posn.x0, posn.y0-0.07, posn.width, cbar_width])
    cbar_ax.tick_params(axis="x", which="major", labelsize=15)
    cbar_ax.xaxis.label.set_size(15)

# Longitude and latitude degrees on the axes
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)
gl.xlabel_style = {'size': 15}
gl.ylabel_style = {'size': 15}

plt.show()

# %%
import matplotlib.patches as mpatches

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_extent([-85, -40, -20, 10], crs=ccrs.PlateCarree())

# Background: Stamen terrain with added Cartopy features
stamen_terrain = cimgt.Stamen('terrain-background')
ax.add_image(stamen_terrain, 8)
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAKES, alpha=0.5)
ax.add_feature(cfeature.RIVERS)

# Add the region shapefile
shape = gpd.read_file("/home/ah2174/shapefiles/Amazon_rainforest_shapefile.zip")
shape.plot(ax=ax, color='none', edgecolor='slategrey', linewidth=1, zorder=5)

# Plot our data
low = quality_gedi_gdf[(quality_gedi_gdf.agcd < 1) & (quality_gedi_gdf.recovery_period > 5)]
high = quality_gedi_gdf[(quality_gedi_gdf.agcd > 100) & (quality_gedi_gdf.recovery_period < 4)]
low.plot(color="red", zorder=10, markersize=3, ax=ax)
high.plot(color="blue", zorder=10, markersize=3, ax=ax)

# Longitude and latitude degrees on the axes
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)
gl.xlabel_style = {'size': 15}
gl.ylabel_style = {'size': 15}

plt.legend(["Low ACD, high recovery", "High ACD, low recovery"], loc=0, frameon=True, fontsize="large", markerscale=5)

plt.show()

high_discrepancies = quality_gedi_gdf[(quality_gedi_gdf.agcd > 100) & (quality_gedi_gdf.recovery_period < 4)]
high_discrepancies.to_csv("~/test/high_discrepancies.csv")

# %%
low_count = len(quality_gedi[(quality_gedi.agcd < 1) & (quality_gedi.recovery_period > 5)])
low_pct = low_count/len(quality_gedi)

high_count = len(quality_gedi[(quality_gedi.agcd > 100) & (quality_gedi.recovery_period < 4)])
high_pct = high_count / len(quality_gedi)

print("Unlikely zeros:")
print("{} ({} %)".format(low_count, low_pct))
print("Unlikely extreme highs:")
print("{} ({} %)".format(high_count, high_pct))
# Out:
# Unlikely zeros:
# 1937 (0.06647220315717227 %)
# Unlikely extreme highs:
# 1028 (0.03527796842827728 %)

# %%
# Number of samples per age group:
print(quality_gedi.groupby('recovery_period').agcd.count())
quality_gedi.recovery_period.quantile(.76)
# Out:
# recovery_period
# 3.0     7172
# 4.0     4740
# 5.0     2761
# 6.0     1719
# 7.0      919
# 8.0     1598
# 9.0     1360
# 10.0    1637
# 11.0    1235
# 12.0    1030
# 13.0     891
# 14.0     648
# 15.0     543
# 16.0     430
# 17.0     440
# 18.0     545
# 19.0     617
# 20.0     406
# 21.0     264
# 22.0     185
# Name: agcd, dtype: int64
# 11.0

# %% [markdown]
# ### 3a. Modeling: Quantile Regression

# %%
# qreg_params = pd.read_feather('/maps/forecol/data/Overlays/monte_carlo/results/nonan/model_results_pctnonan=100_.feather')
# qreg_params = pd.read_feather('/maps/forecol/data/Overlays/monte_carlo/results/std1/model_results_pctnonan=100_maxstd=1_.feather')
qreg_params = pd.read_feather('/maps/forecol/data/Overlays/monte_carlo/results/std0/model_results_pctnonan=100_maxstd=0_.feather')

# %% [markdown]
# ### 3b. Modeling: Linear Regression

# %% [markdown]
# ### 4. Graphs

# %%
from matplotlib.lines import Line2D

plt.figure(1, (10,10))
ax = sns.boxplot(x="recovery_period", y="agcd", data=quality_gedi, color='lightblue', showfliers=False, order=np.arange(23))
ax.set_ylabel("GEDI ACD (MgC/ha)", fontsize=15)
ax.set_xlabel("Recovery Period (years)", fontsize=15)
ax.set_xlim([0,23])
xs = np.arange(0, 23)

# cmap = plt.get_cmap('inferno')
get_ys = lambda a, b: a + b * xs
# for i in range(0,models.shape[0], 10):
#     ys = get_ys(models.a[i], models.b[i])
#     ax.plot(xs, ys, linestyle="dotted", color=cmap(i), label='Quantile {0:.2f}'.format(models.q[i]))
def get_ys_ci(la, lb, ua, ub):
    return (la + ub * xs, ua + lb * xs)


med_ys = get_ys(qreg_params.b0.mean(), qreg_params.b1.mean())
lower_ys, upper_ys = get_ys_ci(qreg_params.b0.quantile(0.025), qreg_params.b1.quantile(0.025), qreg_params.b0.quantile(0.975), qreg_params.b1.quantile(0.975))
ax.plot(xs, med_ys, color="green")
# ci_lines = qreg_params.sample(100)
# for line in ci_lines.iterrows():
#     ax.plot(xs, get_ys(line[1].b0, line[1].b1), color="green", alpha=0.1)
ax.fill_between(xs, lower_ys, upper_ys, color="red", alpha=0.1)

ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.1f'))
ax.set_ylim([0, 80])
yticks = list(ax.get_yticks()[ax.get_yticks() >= 0])
yticks.append(qreg_params.b0.mean())
yticks.sort()
ax.set_yticks(yticks)
ax.tick_params(axis='both', which='major', labelsize=13)

# Add a text annotation for the regression line
text = 'y = {0:.2f} + {1:.2f}x'.format(qreg_params.b0.mean(), qreg_params.b1.mean())
legend_elements = [
        Line2D([0], [0], color='green', label=text,
            markerfacecolor='green', markersize=5)]
# props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
ax.legend(0.05, 0.95, handles=legend_elements, fontsize=14)
# Out:
# /tmp/ipykernel_725692/3326640893.py:41: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   ax.legend(0.05, 0.95, handles=legend_elements, fontsize=14)

# %%
plt.figure(1, (15,10))
ax = sns.violinplot(x="recovery_period", y="agcd", data=quality_gedi, color="lightblue", inner="quartile", order=np.arange(23))
ax.set_ylabel("GEDI ACD (MgC/ha)", fontsize=15)
ax.set_xlabel("Recovery Period (years)", fontsize=15)
ax.set_xlim([0,23])

xs = np.arange(0, 23)

# cmap = plt.get_cmap('inferno')
get_ys = lambda a, b: a + b * xs
# for i in range(0,models.shape[0], 10):
#     ys = get_ys(models.a[i], models.b[i])
#     ax.plot(xs, ys, linestyle="dotted", color=cmap(i), label='Quantile {0:.2f}'.format(models.q[i]))
def get_ys_ci(la, lb, ua, ub):
    return (la + ub * xs, ua + lb * xs)


med_ys = get_ys(qreg_params.b0.mean(), qreg_params.b1.mean())
lower_ys, upper_ys = get_ys_ci(qreg_params.b0.quantile(0.025), qreg_params.b1.quantile(0.025), qreg_params.b0.quantile(0.975), qreg_params.b1.quantile(0.975))
ax.plot(xs, med_ys, color="green")
# ci_lines = qreg_params.sample(100)
# for line in ci_lines.iterrows():
#     ax.plot(xs, get_ys(line[1].b0, line[1].b1), color="green", alpha=0.1)
ax.fill_between(xs, lower_ys, upper_ys, color="green", alpha=0.1)

ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.1f'))
ax.set_ylim([0, 60])
yticks = list(ax.get_yticks()[ax.get_yticks() >= 0])
yticks.append(qreg_params.b0.mean())
yticks.sort()
ax.set_yticks(yticks)
ax.tick_params(axis='both', which='major', labelsize=13)

# %%
# Parameter distribution
fig, ax = plt.subplots(ncols=2, figsize=(10,5))

sns.histplot(qreg_params.b0, ax=ax[0])
ax[0].set_title('Intercept empirical distribution')
ax[0].set_xlabel('Intercept (MgC/ha)')

sns.histplot(qreg_params.b1, ax=ax[1])
ax[1].set_title('Slope empirical distribution')
ax[1].set_xlabel('Slope (MgC/ha/yr)')
# Out:
# Text(0.5, 0, 'Slope (MgC/ha/yr)')

# %%
print("Intercept: {0:.2f}, 95% CI: [{1:.2f}, {2:.2f}]".format(qreg_params.b0.mean(), qreg_params.b0.quantile(0.025), qreg_params.b0.quantile(0.975)))
print("Slope: {0:.2f}, 95% CI: [{1:.2f}, {2:.2f}]".format(qreg_params.b1.mean(), qreg_params.b1.quantile(0.025), qreg_params.b1.quantile(0.975)))
# Out:
# Intercept: 5.07, 95% CI: [4.31, 5.86]
# Slope: 1.84, 95% CI: [1.75, 1.94]

# %%
# Benchmarking
stage_1_times = [13, 15, 16, 15, 15, 15, 14, 13, 12, 11, 11, 17, 20, 19, 18, 17, 17, 17, 15, 14, 13, 11, 12, 15, 14, 12, 12, 12, 11, 9.7, 9.4, 11]
ax = sns.histplot(stage_1_times)
ax.set_xlabel('Runtime (minutes)')
ax.set_ylabel('Task count')
# Out:
# Text(0, 0.5, 'Task count')

# %%
fig, ax = plt.subplots(1, figsize=(5,8))

qg = quality_gedi
n = len(qg)
print(n)
# sample = np.random.choice(n, size=int(n/5), replace=False)
# x = qg.recovery_period.iloc[sample].values
# y = qg.agbd.iloc[sample].values

x = qg.recovery_period.values
y = qg.agcd.values

# Calculate the point density distribution per age group
ages = np.unique(x)
z = np.zeros(y.shape)
for i in ages:
    z[x == i] = gaussian_kde(y[x == i])(y[x == i])


# Sort the points by density, so that the densest points are plotted last
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

# limit to only the points with high enough density
# x = x[z > 0.005]
# y = y[z > 0.005]
# z = z[z > 0.005]

ax.scatter(x, y, c=z, s=110, cmap='PuRd')
ax.set_ylim([0,60])

xs = np.arange(0, 23)
get_ys = lambda a, b: a + b * xs
def get_ys_ci(la, lb, ua, ub):
    return (la + ub * xs, ua + lb * xs)
    
med_ys = get_ys(qreg_params.b0.mean(), qreg_params.b1.mean())
lower_ys, upper_ys = get_ys_ci(qreg_params.b0.quantile(0.025), qreg_params.b1.quantile(0.025), qreg_params.b0.quantile(0.975), qreg_params.b1.quantile(0.975))
ax.plot(xs, med_ys, color="blue")
ax.fill_between(xs, lower_ys, upper_ys, color="blue", alpha=0.1)
ax.set_ylabel("GEDI ACD (MgC/ha)", fontsize=15)
ax.set_xlabel("Recovery Period (years)", fontsize=15)
ax.set_xlim([0,23])
plt.show()
# Out:
# 29203

# %% [markdown]
# ### 5. Cross-validation

# %%
# K-fold cross-validation for the median quantile regression line
# Returns array of error results on each split.

def check_function(q, ys, predictions):
    abs_err = (ys - predictions).abs()
    penalty_under = (q * abs_err[predictions <= ys]).sum()
    penalty_over = ((1 - q) * abs_err[predictions > ys]).sum()
    return (penalty_under + penalty_over) / len(ys)

def compute_qreg_error(model, q, data, predictor, response):
    a = qreg_params.b0.mean()
    b = qreg_params.b1.mean()
    predictions = a + b * data[predictor]
    return check_function(q, data[response], predictions) 


def cross_validate_qregression(
    q: float, n_splits: int, data: pd.DataFrame, predictor: str, response: str):
    kf = KFold(n_splits=n_splits, shuffle=True)
    qregs = []
    for train_index, test_index in kf.split(data):
        train = data.iloc[train_index].loc[:, [predictor, response]]
        test =  data.iloc[test_index][[predictor, response]]

        mod = smf.quantreg(response + ' ~ ' + predictor, train)
        model = mod.fit(q=q)

        qregs.append(compute_qreg_error(model, q, test, predictor, response))

    return np.array(qregs)

# %%
qregs = cross_validate_qregression(
    q=0.36,
    n_splits=10,
    data=quality_gedi,
    predictor='recovery_period',
    response='agcd'
)
print(qregs)
print(qregs.mean())
# Out:
# [15.42950159 15.08022283 15.39676996 15.07112365 15.756576   15.55263866
#  15.42889689 15.71436642 15.36779398 14.96040177]
# 15.375829175343355

# %%
import statsmodels.formula.api as smf

# Add column of residuals to dataframe
q=0.5
mod = smf.quantreg('agcd ~ recovery_period', quality_gedi)
median_model = mod.fit(q=q)

predictions = median_model.params['Intercept'] + median_model.params['recovery_period'] * quality_gedi['recovery_period']
quality_gedi['median_error'] = predictions - quality_gedi['agcd']

abs_err = quality_gedi.median_error.abs()
quality_gedi['median_qreg_error'] = np.zeros_like(abs_err)
quality_gedi.loc[quality_gedi.median_error <= 0, 'median_qreg_error']  = q * abs_err[quality_gedi.median_error <= 0]
quality_gedi.loc[quality_gedi.median_error > 0, 'median_qreg_error'] = (1 - q) * abs_err[quality_gedi.median_error > 0]
# Out:
# /tmp/ipykernel_384253/334351318.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quality_gedi['median_error'] = predictions - quality_gedi['agcd']
# /tmp/ipykernel_384253/334351318.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quality_gedi['median_qreg_error'] = np.zeros_like(abs_err)

# %%
# Plot model residuals (histogram)
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
sns.histplot(quality_gedi, x='median_error', ax=axs[0, 0])
axs[0, 0].set_xlim(-200, 50)
axs[0, 0].set_xlabel('Residuals (median model)')
sns.histplot(quality_gedi, x='median_qreg_error', ax=axs[0, 1])
axs[0, 1].set_xlim(0, 8.2 + 12.3 * 4.4)
axs[0, 1].set_xlabel('Quantile regression error value (median model)')
sns.scatterplot(data=quality_gedi, x='recovery_period', y='median_error', ax=axs[1,0])
sns.scatterplot(data=quality_gedi, x='agcd', y='median_error', ax=axs[1,1])
axs[1,1].set_xlim(0,80)
print(quality_gedi.median_error.describe())
print(quality_gedi.median_qreg_error.describe())
# Out:
# count    29140.000000
# mean       -27.317102
# std         67.434471
# min      -1542.660759
# 25%        -42.298273
# 50%          0.000004
# 75%          9.354713
# max         45.996593
# Name: median_error, dtype: float64
# count    2.914000e+04
# mean     1.941727e+01
# std      3.076314e+01
# min      3.563451e-07
# 25%      4.127401e+00
# 50%      7.174512e+00
# 75%      2.129539e+01
# max      7.713304e+02
# Name: median_qreg_error, dtype: float64

# %% [markdown]
# ### 6. Spatial (Auto)correlation

# %%
# Plot variogram based on residuals

# Sample a random selection of data points
k = 4      # Randomly sample 1/k th of the points
np.random.seed(42)
idxs = np.random.randint(0, len(quality_gedi), (int(len(quality_gedi) / k)))
coords = quality_gedi.iloc[idxs][['lon_lowestmode', 'lat_lowestmode']].to_numpy()
values = quality_gedi.iloc[idxs]['median_error'].abs().to_numpy()
V = skg.Variogram(
    coords,         # Spatial coordinates
    values,         # Residuals
    maxlag=2,       # Maximum distance (in lon,lat units) between data points to consider
    n_lags=30,
)
V.estimator = 'cressie'
V.plot()
V.distance_difference_plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ah2174/biomass-recovery/notebooks/exploratory/26-ah2174-gedi-recovery-analysis.ipynb Cell 29 in <module>
#      <a href='vscode-notebook-cell://ssh-remote%2Bsherwood/home/ah2174/biomass-recovery/notebooks/exploratory/26-ah2174-gedi-recovery-analysis.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> V.estimator = 'cressie'
#      <a href='vscode-notebook-cell://ssh-remote%2Bsherwood/home/ah2174/biomass-recovery/notebooks/exploratory/26-ah2174-gedi-recovery-analysis.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> V.plot()
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bsherwood/home/ah2174/biomass-recovery/notebooks/exploratory/26-ah2174-gedi-recovery-analysis.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> V.distance_difference_plot()
#
# ...

# %% [markdown]
# ### Other ...

# %%
tot = len(l4a_data)
lst = []
lst.append(len(l4a_data[l4a_data.overlap_quality != 0]))
lst.append(len(l4a_data[(l4a_data.recovery_period >= 3) & (l4a_data.recovery_period <= 22)]))
lst.append(len(l4a_data[l4a_data.l4_quality_flag == 1]))
lst.append(len(l4a_data[l4a_data.l2_quality_flag == 1]))
lst.append(len(l4a_data[l4a_data.degrade_flag == 0]))

for el in lst:
    print(f"{el}: {el/tot * 100}%")

print(tot)
a = len(quality_gedi[quality_gedi.agbd < 99])
print(f"{a}: {a/len(quality_gedi) * 100}%")
# Out:
# 626313: 28.48826128783554%
# 1794028: 81.60255083591275%
# 1630945: 74.18461265547568%
# 1987172: 90.38783349518647%
# 1672236: 76.06276111612716%
# 2198495
# 84805: 88.01947108398721%

# %%
sns.histplot(quality_gedi[quality_gedi.recovery_period == 22], x='agcd')

yr_22 = quality_gedi[quality_gedi.recovery_period == 22]

print(len(yr_22))
print(len(yr_22[yr_22.agcd == 0]))
bins = [0,1,2,3,4,5,400]
print(yr_22['agcd'].value_counts(bins=bins, sort=False))
# Out:
# 801
# 28
# (-0.001, 1.0]     61
# (1.0, 2.0]         6
# (2.0, 3.0]        11
# (3.0, 4.0]         9
# (4.0, 5.0]         3
# (5.0, 400.0]     710
# Name: agcd, dtype: int64
