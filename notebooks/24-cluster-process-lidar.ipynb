# %% [markdown]
# # 24. Lidar point cloud cluster processing

# %% [markdown]
# This notebooks sets up files to process all Lidar point clouds on the Jassmin cluster

# %%
# Convenient jupyter setup
# %load_ext autoreload
# %autoreload 2

# %%
import geopandas as gpd
import pandas as pd
import pathlib
import os
import datetime
from tqdm.autonotebook import tqdm

from src.constants import USER_PATH, PAISAGENSLIDAR_PATH, EBALIDAR_PATH, SCRATCH_PATH
from src.utils.os import list_content, latest_matching_file
from src.utils.slurm import sbatch_header, sbatch

from src.processing.slurm_jobcreator import lidR_gridmetrics_job, lidR_processing_job
# Out:
# /tmp/ipykernel_19600/760213292.py:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# ### Helper functions

# %%
is_empty = lambda folder: not any(folder.iterdir())
contains = lambda folder, name: len(list(folder.glob(name))) > 0

# %% [markdown]
# ## 1. Paisagenslidar - Cluster normalisation

# %%
paisagens_meta_path = latest_matching_file(PAISAGENSLIDAR_PATH / "*metadata")
paisagens_meta = gpd.read_file(paisagens_meta_path)

# %%
paisagens_paths = paisagens_meta.groupby("survey").first().path.apply(lambda x: pathlib.Path(x).parent)
paisagens_years = paisagens_meta.groupby("survey")[["year", "crs", "region", "plot_code", "creation_date"]].first()
paisagens_nfiles = paisagens_meta.groupby("survey").filename.count()
paisagens_size = paisagens_meta.groupby("survey")[["area (ha)",  "file_size (MB)", "points (Mio.)"]].sum()

# %%
paisagens_surveys = pd.concat([paisagens_paths, paisagens_years, paisagens_nfiles, paisagens_size], join="inner", axis=1)
paisagens_surveys["name"] = paisagens_surveys.apply(lambda x: f"{x.region}_{x.plot_code}_{x.year}", axis=1)
paisagens_surveys = paisagens_surveys.sort_values(by=["year", "region", "plot_code"])

# %% [markdown]
# ### Optional
# At this point, it may be prudent to test processing a single file to ensure that things are in good working order before issuing batch jobs.
#
# The following code should complete without error.
#
# Output files will be placed in the scratch directory (/work/scratch-nopw on JASMIN)

# %%
import subprocess
survey = paisagens_surveys[paisagens_surveys.name == "CUI_A01_2008"]

out_dir = SCRATCH_PATH / "Paisagenslidar" / "processed" / str(survey["year"].values[0]) / survey["name"].values[0]
print(survey['path'].values[0])
print(out_dir)

job_file = lidR_processing_job(lidar_path=(survey['path'].values[0]),
                                survey_name=survey['name'].values[0], 
                                out_dir = out_dir,
                                queue="short-serial",
                                max_time = datetime.time(23, 59, 0),
                                chunk_size=0,
                                buffer=50,
                                filter_quantile = 0.95,
                                filter_sensitivity = 1.1,
                                filter_gridsize= 10,
                                as_file=True, 
                                perform_check=False,
                                compress_intermediates=True, 
                                required_memory_per_node=15000,
                                )
    
subprocess.run('sh', job_file)
# Out:
# /gws/nopw/j04/forecol/data/Paisagenslidar/Mission_2008/CUI_A01_2008_LiDAR/CUI_A01_2008_laz
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/CUI_A01_2008
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/CUI_A01_2008/slurm/slurm_CUI_A01_2008.sh
# Submitted batch job 11755665
# Submitted job for survey
# CUI_A01_2008_laz    CUI_A01_2008
# Name: name, dtype: object

# %% [markdown]
# ### Normalisation: Create slurm job
#
# You can check running jobs with the following command (Formatting string to show full job names and info):
# ```
# $ squeue --format="%.18i %.9P %.30j %.8u %.8T %.10M %.9l %.6D %R"  | grep $USER
# ```

# %%
for idx, survey in tqdm(paisagens_surveys.iterrows(), total=len(paisagens_surveys)):

    out_dir = SCRATCH_PATH / "Paisagenslidar" / "processed" / str(survey["year"]) / survey["name"]
    # out_dir = PAISAGENSLIDAR_PATH / "processed" / str(survey["year"]) / survey["name"]

    # The processing job creates the following folders:
    # csf_ground: Classification of ground points
    # normalised: Height normalisation based on ground points
    # processed: Noise filtering; final results of normalisation
    # If the "processed" directory already exists and is non-empty, do not re-process the data
    if contains(out_dir, "processed") and not is_empty(out_dir / "processed"):
        continue
    
    job_file = lidR_processing_job(lidar_path=survey.path,
                                   survey_name=survey.name, 
                                   out_dir = out_dir,
                                   queue="short-serial",
                                   max_time = datetime.time(23, 59, 0),
                                   chunk_size=0,
                                   buffer=50,
                                   filter_quantile = 0.95,
                                   filter_sensitivity = 1.1,
                                   filter_gridsize= 10,
                                   as_file=True, 
                                   perform_check=False,
                                   compress_intermediates=True, 
                                   required_memory_per_node=15000,
                                  )
        
    print(job_file)
    break
    # Submit job
    sbatch(job_file)
    print(f"Submitted job for {survey['name']}")
# Out:
#   0%|          | 0/160 [00:00<?, ?it/s]
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/DUC_A01_2008/slurm/slurm_DUC_A01_2008_laz.sh
# Submitted batch job 11891408
# Submitted job for DUC_A01_2008
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/TAP_A01_2008/slurm/slurm_TAP_A01_2008_laz.sh
# Submitted batch job 11891414
# Submitted job for TAP_A01_2008
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/TAP_A04_2008/slurm/slurm_TAP_A04_2008_laz.sh
# Submitted batch job 11891420
# Submitted job for TAP_A04_2008
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2012/TAP_A02_2012/slurm/slurm_TAP_A02_2012_laz.sh
# Submitted batch job 11891429
# Submitted job for TAP_A02_2012
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/BAR_A01_2014/slurm/slurm_BAR_A01_2014_laz.sh
# Submitted batch job 11891439
# Submitted job for BAR_A01_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/CAU_A01_2014/slurm/slurm_CAU_A01_2014_laz.sh
# Submitted batch job 11891441
# Submitted job for CAU_A01_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/FNB_A01_2014/slurm/slurm_FNB_A01_2014_laz.sh
# Submitted batch job 11891443
# Submitted job for FNB_A01_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/RIB_A01_2014/slurm/slurm_RIB_A01_2014_laz.sh
# Submitted batch job 11891448
# Submitted job for RIB_A01_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/PRU_A01_2017/slurm/slurm_PRU_A01_2017_LiDAR.sh
# Submitted batch job 11891462
# Submitted job for PRU_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/PRU_A10_2017/slurm/slurm_PRU_A10_2017_LiDAR.sh
# Submitted batch job 11891465
# Submitted job for PRU_A10_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/PRU_A14_2017/slurm/slurm_PRU_A14_2017_LiDAR.sh
# Submitted batch job 11891469
# Submitted job for PRU_A14_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/PRU_A26_2017/slurm/slurm_PRU_A26_2017_LiDAR.sh
# Submitted batch job 11891473
# Submitted job for PRU_A26_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/SDM_A01_2017/slurm/slurm_SDM_A01_2017_laz.sh
# Submitted batch job 11891476
# Submitted job for SDM_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/TAP_A01_2017/slurm/slurm_TAP_A01_2017_las.sh
# Submitted batch job 11891479
# Submitted job for TAP_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/ANA_A01_2018/slurm/slurm_ANA_A01_2018_LAS.sh
# Submitted batch job 11891484
# Submitted job for ANA_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/BON_A01_2018/slurm/slurm_BON_A01_2018_LAS.sh
# Submitted batch job 11891488
# Submitted job for BON_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/FNA_A01_2018/slurm/slurm_FNA_A01_2018_LAS.sh
# Submitted batch job 11891491
# Submitted job for FNA_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/FNE_A01_2018/slurm/slurm_FNE_A01_2018_LAS.sh
# Submitted batch job 11891494
# Submitted job for FNE_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/HUM_A01_2018/slurm/slurm_HUM_A01_2018_LAS.sh
# Submitted batch job 11891498
# Submitted job for HUM_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/RIB_A01_2018/slurm/slurm_RIB_A01_2018_LAS.sh
# Submitted batch job 11891501
# Submitted job for RIB_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAL_A01_2018/slurm/slurm_TAL_A01_2018_LAS.sh
# Submitted batch job 11891504
# Submitted job for TAL_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAN_A01_2018/slurm/slurm_TAN_A01_2018_LAS.sh
# Submitted batch job 11891507
# Submitted job for TAN_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAP_A02_2018/slurm/slurm_TAP_A02_2018_LAS.sh
# Submitted job for TAP_A02_2018
# Submitted batch job 11891510
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAP_A03_2018/slurm/slurm_TAP_A03_2018_LAS.sh
# Submitted job for TAP_A03_2018
# Submitted batch job 11891514
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAP_A04_2018/slurm/slurm_TAP_A04_2018_LAS.sh
# Submitted batch job 11891517
# Submitted job for TAP_A04_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAP_A05_2018/slurm/slurm_TAP_A05_2018_LAS.sh
# Submitted batch job 11891520
# Submitted job for TAP_A05_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAP_A06_2018/slurm/slurm_TAP_A06_2018_LAS.sh
# Submitted batch job 11891524
# Submitted job for TAP_A06_2018

# %% [markdown]
# ### Metrics: Create slurm job

# %%
unavailable = []
for idx, survey in paisagens_surveys.iterrows():
    
    if survey["path"] is None or pd.isna(survey["path"]):
        continue
    
    if os.getenv("USE_SCRATCH"):
        out_dir = SCRATCH_PATH / "Paisagenslidar" / "processed" / str(survey["year"]) / survey["name"]
    else:
        out_dir = PAISAGENSLIDAR_PATH / "processed" / str(survey["year"]) / survey["name"]
    
    # The processing job stores its output in the folder grid_metrics.
    # If this folder already exists and is not empty, do not reprocess.
    # TODO: Move this check intor slurm_jobcreator.py
    if contains(out_dir, "grid_metrics") and not is_empty(out_dir / "grid_metrics"):
        continue
    
    # If the LiDAR data was not successfully normalised in the step above,
    # Print a warning and continue
    if not (out_dir / "processed").exists() or is_empty(out_dir / "processed"):
        unavailable.append(survey["name"])
        continue
    
    job_file = lidR_gridmetrics_job(lidar_path=out_dir/"processed",
                                    survey_name=survey.name, 
                                    out_dir=out_dir,
                                    metrics = {"n_points": [1],
                                               "n_pulses": [1],
                                               "n_ground_points": [1],
                                               "max": [10, 50],
                                               "quantile_0.05": [10, 50],
                                               "quantile_0.1": [10, 50],
                                               "kurtosis": [10, 50],
                                               "mean": [10, 50],
                                               "interquartile_range": [10, 50],
                                               "longo_biomass": [10, 50], 
                                               "canopy_height": [1]

                                    },
                                    buffer = 10,
                                    chunk_size = 0,
                                    as_file = True,
                                    overwrite=False,
                                    queue="short-serial",
                                    required_memory_per_node=8000,    
                                    max_time = datetime.time(10, 0, 0)
                                   )
    print(job_file)
    break
    # Submit job
    sbatch(job_file)
    print(f"Submitted job for {survey['name']}")

if len(unavailable) > 0:
    print("Could not find normalized input data for the following {} surveys:".format(len(unavailable)))
    for s in unavailable:
        print(s)
# Out:
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/CUI_A01_2008/slurm/slurm_CUI_A01_2008_laz_grid_metrics.sh
# Submitted batch job 11983452
# Submitted job for CUI_A01_2008
# DUC_A01_2008 not available.
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/PRE_A01_2008/slurm/slurm_PRE_A01_2008_laz_grid_metrics.sh
# Submitted batch job 11983453
# Submitted job for PRE_A01_2008
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/PRE_A02_2008/slurm/slurm_PRE_A02_2008_laz_grid_metrics.sh
# Submitted batch job 11983454
# Submitted job for PRE_A02_2008
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/PRE_A04_2008/slurm/slurm_PRE_A04_2008_laz_grid_metrics.sh
# Submitted batch job 11983455
# Submitted job for PRE_A04_2008
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/PRE_A05_2008/slurm/slurm_PRE_A05_2008_laz_grid_metrics.sh
# Submitted batch job 11983456
# Submitted job for PRE_A05_2008
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/PRE_A06_2008/slurm/slurm_PRE_A06_2008_laz_grid_metrics.sh
# Submitted batch job 11983457
# Submitted job for PRE_A06_2008
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/PRE_A07_2008/slurm/slurm_PRE_A07_2008_laz_grid_metrics.sh
# Submitted batch job 11983458
# Submitted job for PRE_A07_2008
# TAP_A01_2008 not available.
# TAP_A04_2008 not available.
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/TAP_A05_2008/slurm/slurm_TAP_A05_2008_laz_grid_metrics.sh
# Submitted batch job 11983459
# Submitted job for TAP_A05_2008
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2008/TAP_A06_2008/slurm/slurm_TAP_A06_2008_laz_grid_metrics.sh
# Submitted batch job 11983460
# Submitted job for TAP_A06_2008
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2011/ANT_A01_2011/slurm/slurm_ANT_A01_2011_laz_grid_metrics.sh
# Submitted batch job 11983461
# Submitted job for ANT_A01_2011
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2011/COT_A01_2011/slurm/slurm_COT_A01_2011_laz_grid_metrics.sh
# Submitted batch job 11983462
# Submitted job for COT_A01_2011
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2011/JAM_A01_2011/slurm/slurm_JAM_A01_2011_laz_grid_metrics.sh
# Submitted batch job 11983463
# Submitted job for JAM_A01_2011
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2011/JAM_A02_2011/slurm/slurm_JAM_A02_2011_laz_grid_metrics.sh
# Submitted batch job 11983464
# Submitted job for JAM_A02_2011
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2012/CAU_A01_2012/slurm/slurm_CAU_A01_2012_laz_grid_metrics.sh
# Submitted batch job 11983465
# Submitted job for CAU_A01_2012
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2012/DUC_A01_2012/slurm/slurm_DUC_A01_2012_laz_grid_metrics.sh
# Submitted batch job 11983466
# Submitted job for DUC_A01_2012
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2012/SDM_A01_2012/slurm/slurm_SDM_A01_2012_laz_grid_metrics.sh
# Submitted batch job 11983467
# Submitted job for SDM_A01_2012
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2012/SFX_A01_2012/slurm/slurm_SFX_A01_2012_laz_grid_metrics.sh
# Submitted batch job 11983468
# Submitted job for SFX_A01_2012
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2012/SFX_A02_2012/slurm/slurm_SFX_A02_2012_laz_grid_metrics.sh
# Submitted batch job 11983469
# Submitted job for SFX_A02_2012
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2012/TAN_A01_2012/slurm/slurm_TAN_A01_2012_laz_grid_metrics.sh
# Submitted batch job 11983470
# Submitted job for TAN_A01_2012
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2012/TAP_A01_2012/slurm/slurm_TAP_A01_2012_laz_grid_metrics.sh
# Submitted batch job 11983471
# Submitted job for TAP_A01_2012
# TAP_A02_2012 not available.
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2012/TAP_A03_2012/slurm/slurm_TAP_A03_2012_laz_grid_metrics.sh
# Submitted batch job 11983472
# Submitted job for TAP_A03_2012
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/AND_A01_2013/slurm/slurm_AND_A01_2013_laz_grid_metrics.sh
# Submitted batch job 11983473
# Submitted job for AND_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/AND_A01_2013/slurm/slurm_AND_A01_2013_laz_optional_grid_metrics.sh
# Submitted batch job 11983474
# Submitted job for AND_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/BON_A01_2013/slurm/slurm_BON_A01_2013_laz_grid_metrics.sh
# Submitted batch job 11983475
# Submitted job for BON_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/CAG_A01_2013/slurm/slurm_CAG_A01_2013_laz_grid_metrics.sh
# Submitted batch job 11983476
# Submitted job for CAG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/FNA_A01_2013/slurm/slurm_FNA_A01_2013_laz_grid_metrics.sh
# Submitted batch job 11983477
# Submitted job for FNA_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/FST_A01_2013/slurm/slurm_FST_A01_2013_laz_grid_metrics.sh
# Submitted batch job 11983478
# Submitted job for FST_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/HUM_A01_2013/slurm/slurm_HUM_A01_2013_laz_grid_metrics.sh
# Submitted batch job 11983479
# Submitted job for HUM_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/JAM_A02_2013/slurm/slurm_JAM_A02_2013_laz_grid_metrics.sh
# Submitted batch job 11983480
# Submitted job for JAM_A02_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/JAM_A03_2013/slurm/slurm_JAM_A03_2013_laz_grid_metrics.sh
# Submitted batch job 11983481
# Submitted job for JAM_A03_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PAR_A01_2013/slurm/slurm_PAR_A01_2013_laz_grid_metrics.sh
# Submitted batch job 11983482
# Submitted job for PAR_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PAR_A01_2013/slurm/slurm_PAR_A01_2013_laz_optional_grid_metrics.sh
# Submitted batch job 11983483
# Submitted job for PAR_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P01a_laz_grid_metrics.sh
# Submitted batch job 11983484
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P02a_laz_grid_metrics.sh
# Submitted batch job 11983485
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P03a_laz_grid_metrics.sh
# Submitted batch job 11983486
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P04a_laz_grid_metrics.sh
# Submitted batch job 11983487
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P05a_laz_grid_metrics.sh
# Submitted batch job 11983488
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P05b_laz_grid_metrics.sh
# Submitted batch job 11983489
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P06a_laz_grid_metrics.sh
# Submitted batch job 11983490
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P06b_laz_grid_metrics.sh
# Submitted batch job 11983491
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P07a_laz_grid_metrics.sh
# Submitted batch job 11983492
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P07b_laz_grid_metrics.sh
# Submitted batch job 11983493
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P08a_laz_grid_metrics.sh
# Submitted batch job 11983494
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P08b_laz_grid_metrics.sh
# Submitted batch job 11983495
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P09a_laz_grid_metrics.sh
# Submitted batch job 11983496
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P09b_laz_grid_metrics.sh
# Submitted batch job 11983497
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P10a_laz_grid_metrics.sh
# Submitted batch job 11983498
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P11a_laz_grid_metrics.sh
# Submitted batch job 11983499
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P11b_laz_grid_metrics.sh
# Submitted batch job 11983500
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P12a_laz_grid_metrics.sh
# Submitted batch job 11983501
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P12b_laz_grid_metrics.sh
# Submitted batch job 11983502
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P13a_laz_grid_metrics.sh
# Submitted batch job 11983503
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P14a_laz_grid_metrics.sh
# Submitted batch job 11983504
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P14b_laz_grid_metrics.sh
# Submitted batch job 11983505
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P15a_laz_grid_metrics.sh
# Submitted batch job 11983507
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P15b_laz_grid_metrics.sh
# Submitted batch job 11983509
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P16a_laz_grid_metrics.sh
# Submitted batch job 11983510
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P17a_laz_grid_metrics.sh
# Submitted batch job 11983512
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P18a_laz_grid_metrics.sh
# Submitted batch job 11983513
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P18b_laz_grid_metrics.sh
# Submitted batch job 11983515
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P19a_laz_grid_metrics.sh
# Submitted batch job 11983516
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P20a_laz_grid_metrics.sh
# Submitted batch job 11983518
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P21a_laz_grid_metrics.sh
# Submitted batch job 11983519
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P21b_laz_grid_metrics.sh
# Submitted batch job 11983521
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P22a_laz_grid_metrics.sh
# Submitted batch job 11983522
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P23a_laz_grid_metrics.sh
# Submitted batch job 11983524
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P24a_laz_grid_metrics.sh
# Submitted job for PRG_A01_2013
# Submitted batch job 11983525
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P24b_laz_grid_metrics.sh
# Submitted batch job 11983527
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P25a_laz_grid_metrics.sh
# Submitted batch job 11983529
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P26a_laz_grid_metrics.sh
# Submitted batch job 11983530
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P26b_laz_grid_metrics.sh
# Submitted batch job 11983532
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P27a_laz_grid_metrics.sh
# Submitted batch job 11983533
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P28a_laz_grid_metrics.sh
# Submitted batch job 11983535
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P28b_laz_grid_metrics.sh
# Submitted batch job 11983536
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P29a_laz_grid_metrics.sh
# Submitted batch job 11983538
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P29b_laz_grid_metrics.sh
# Submitted batch job 11983539
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/PRG_A01_2013/slurm/slurm_PRG_A01_2013_P30a_laz_grid_metrics.sh
# Submitted batch job 11983541
# Submitted job for PRG_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/TAC_A01_2013/slurm/slurm_TAC_A01_2013_laz_grid_metrics.sh
# Submitted batch job 11983542
# Submitted job for TAC_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/TAL_A01_2013/slurm/slurm_TAL_A01_2013_laz_grid_metrics.sh
# Submitted batch job 11983544
# Submitted job for TAL_A01_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/TAP_A02_2013/slurm/slurm_TAP_A02_2013_laz_grid_metrics.sh
# Submitted batch job 11983545
# Submitted job for TAP_A02_2013
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2013/TAP_A03_2013/slurm/slurm_TAP_A03_2013_laz_grid_metrics.sh
# Submitted batch job 11983547
# Submitted job for TAP_A03_2013
# BAR_A01_2014 not available.
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/CAN_A01_2014/slurm/slurm_CAN_A01_2014_laz_grid_metrics.sh
# Submitted batch job 11983548
# Submitted job for CAN_A01_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/CAN_A02_2014/slurm/slurm_CAN_A02_2014_laz_grid_metrics.sh
# Submitted batch job 11983549
# Submitted job for CAN_A02_2014
# CAU_A01_2014 not available.
# FNB_A01_2014 not available.
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/FST_A01a_2014/slurm/slurm_FST_A01a_2014_laz_grid_metrics.sh
# Submitted batch job 11983550
# Submitted job for FST_A01a_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/FST_A01b_2014/slurm/slurm_FST_A01b_2014_laz_grid_metrics.sh
# Submitted batch job 11983551
# Submitted job for FST_A01b_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/FST_A02_2014/slurm/slurm_FST_A02_2014_laz_grid_metrics.sh
# Submitted batch job 11983552
# Submitted job for FST_A02_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/FST_A03_2014/slurm/slurm_FST_A03_2014_laz_grid_metrics.sh
# Submitted batch job 11983553
# Submitted job for FST_A03_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/FST_A04_2014/slurm/slurm_FST_A04_2014_laz_grid_metrics.sh
# Submitted batch job 11983554
# Submitted job for FST_A04_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/FST_A05_2014/slurm/slurm_FST_A05_2014_laz_grid_metrics.sh
# Submitted batch job 11983555
# Submitted job for FST_A05_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/FST_A06_2014/slurm/slurm_FST_A06_2014_laz_grid_metrics.sh
# Submitted batch job 11983556
# Submitted job for FST_A06_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/JAM_A02a_2014/slurm/slurm_JAM_A02a_2014_laz_grid_metrics.sh
# Submitted batch job 11983557
# Submitted job for JAM_A02a_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/JAM_A02b_2014/slurm/slurm_JAM_A02b_2014_laz_grid_metrics.sh
# Submitted batch job 11983558
# Submitted job for JAM_A02b_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/JAM_A03_2014/slurm/slurm_JAM_A03_2014_laz_grid_metrics.sh
# Submitted batch job 11983559
# Submitted job for JAM_A03_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/JAM_A04_2014/slurm/slurm_JAM_A04_2014_laz_grid_metrics.sh
# Submitted batch job 11983560
# Submitted job for JAM_A04_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/JAM_A05_2014/slurm/slurm_JAM_A05_2014_laz_grid_metrics.sh
# Submitted job for JAM_A05_2014
# Submitted batch job 11983561
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/JAM_A06_2014/slurm/slurm_JAM_A06_2014_laz_grid_metrics.sh
# Submitted batch job 11983562
# Submitted job for JAM_A06_2014
# RIB_A01_2014 not available.
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/SAN_A01_2014/slurm/slurm_SAN_A01_2014_laz_grid_metrics.sh
# Submitted batch job 11983563
# Submitted job for SAN_A01_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/SAN_A02_2014/slurm/slurm_SAN_A02_2014_laz_grid_metrics.sh
# Submitted batch job 11983564
# Submitted job for SAN_A02_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2014/TAN_A01_2014/slurm/slurm_TAN_A01_2014_laz_grid_metrics.sh
# Submitted batch job 11983565
# Submitted job for TAN_A01_2014
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/CON_A01_2015/slurm/slurm_CON_A01_2015_LAS_grid_metrics.sh
# Submitted batch job 11983566
# Submitted job for CON_A01_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/FST_A01a_2015/slurm/slurm_FST_A01a_2015_LiDAR_grid_metrics.sh
# Submitted job for FST_A01a_2015
# Submitted batch job 11983569
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/FST_A03_2015/slurm/slurm_FST_A03_2015_LiDAR_grid_metrics.sh
# Submitted batch job 11983574
# Submitted job for FST_A03_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/FST_A05_2015/slurm/slurm_FST_A05_2015_LiDAR_grid_metrics.sh
# Submitted batch job 11983576
# Submitted job for FST_A05_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/FST_A06_2015/slurm/slurm_FST_A06_2015_LiDAR_grid_metrics.sh
# Submitted job for FST_A06_2015
# Submitted batch job 11983578
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/FST_A07_2015/slurm/slurm_FST_A07_2015_LiDAR_grid_metrics.sh
# Submitted batch job 11983583
# Submitted job for FST_A07_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/FST_A08_2015/slurm/slurm_FST_A08_2015_LiDAR_grid_metrics.sh
# Submitted batch job 11983585
# Submitted job for FST_A08_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/JAC_A01_2015/slurm/slurm_JAC_A01_2015_laz_grid_metrics.sh
# Submitted batch job 11983588
# Submitted job for JAC_A01_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/JAC_A02_2015/slurm/slurm_JAC_A02_2015_laz_grid_metrics.sh
# Submitted batch job 11983589
# Submitted job for JAC_A02_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/JAC_A03_2015/slurm/slurm_JAC_A03_2015_laz_grid_metrics.sh
# Submitted batch job 11983590
# Submitted job for JAC_A03_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/JAC_A04_2015/slurm/slurm_JAC_A04_2015_laz_grid_metrics.sh
# Submitted batch job 11983591
# Submitted job for JAC_A04_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/JAC_A05_2015/slurm/slurm_JAC_A05_2015_LiDAR_grid_metrics.sh
# Submitted batch job 11983592
# Submitted job for JAC_A05_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/JAM_A02c_2015/slurm/slurm_JAM_A02c_2015_LiDAR_grid_metrics.sh
# Submitted batch job 11983593
# Submitted job for JAM_A02c_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/JAM_A07_2015/slurm/slurm_JAM_A07_2015_LiDAR_grid_metrics.sh
# Submitted batch job 11983594
# Submitted job for JAM_A07_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2015/JAM_A08_2015/slurm/slurm_JAM_A08_2015_LiDAR_grid_metrics.sh
# Submitted batch job 11983595
# Submitted job for JAM_A08_2015
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2016/TAP_A02_2016/slurm/slurm_TAP_A02_2016_LiDAR_grid_metrics.sh
# Submitted batch job 11983596
# Submitted job for TAP_A02_2016
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2016/TAP_A03_2016/slurm/slurm_TAP_A03_2016_LiDAR_grid_metrics.sh
# Submitted batch job 11983597
# Submitted job for TAP_A03_2016
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/ANA_A01_2017/slurm/slurm_ANA_A01_2017_laz_grid_metrics.sh
# Submitted batch job 11983598
# Submitted job for ANA_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/AND_A01_2017/slurm/slurm_AND_A01_2017_LiDAR_grid_metrics.sh
# Submitted batch job 11983599
# Submitted job for AND_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/CAN_A01_2017/slurm/slurm_CAN_A01_2017_LiDAR_grid_metrics.sh
# Submitted batch job 11983600
# Submitted job for CAN_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/CAN_A02_2017/slurm/slurm_CAN_A02_2017_LiDAR_grid_metrics.sh
# Submitted batch job 11983601
# Submitted job for CAN_A02_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/CAU_A01_2017/slurm/slurm_CAU_A01_2017_LAS_grid_metrics.sh
# Submitted batch job 11983602
# Submitted job for CAU_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/DUC_A01_2017/slurm/slurm_DUC_A01_2017_LiDAR_grid_metrics.sh
# Submitted batch job 11983603
# Submitted job for DUC_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/FNC_A01_2017/slurm/slurm_FNC_A01_2017_laz_grid_metrics.sh
# Submitted job for FNC_A01_2017
# Submitted batch job 11983604
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/FNC_A02_2017/slurm/slurm_FNC_A02_2017_las_grid_metrics.sh
# Submitted batch job 11983605
# Submitted job for FNC_A02_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/FNC_A03_2017/slurm/slurm_FNC_A03_2017_laz_grid_metrics.sh
# Submitted batch job 11983606
# Submitted job for FNC_A03_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/FNC_A04_2017/slurm/slurm_FNC_A04_2017_laz_grid_metrics.sh
# Submitted batch job 11983607
# Submitted job for FNC_A04_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/FND_A01_2017/slurm/slurm_FND_A01_2017_LiDAR_grid_metrics.sh
# Submitted batch job 11983608
# Submitted job for FND_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/FND_A02_2017/slurm/slurm_FND_A02_2017_laz_grid_metrics.sh
# Submitted batch job 11983609
# Submitted job for FND_A02_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/FND_A03_2017/slurm/slurm_FND_A03_2017_laz_grid_metrics.sh
# Submitted job for FND_A03_2017
# Submitted batch job 11983610
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/MMA_A01_2017/slurm/slurm_MMA_A01_2017_laz_grid_metrics.sh
# Submitted batch job 11983611
# Submitted job for MMA_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/PAR_A01_2017/slurm/slurm_PAR_A01_2017_LiDAR_grid_metrics.sh
# Submitted batch job 11983612
# Submitted job for PAR_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/PRG_A01_2017/slurm/slurm_LAZ_grid_metrics.sh
# Submitted batch job 11983613
# Submitted job for PRG_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/PRG_A01_2017/slurm/slurm_PRG_A01_2017_P23_las_grid_metrics.sh
# Submitted batch job 11983614
# Submitted job for PRG_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/PRU_A01_2017/slurm/slurm_PRU_A01_2017_LiDAR_grid_metrics.sh
# Submitted batch job 11983615
# Submitted job for PRU_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/PRU_A10_2017/slurm/slurm_PRU_A10_2017_LiDAR_grid_metrics.sh
# Submitted batch job 11983616
# Submitted job for PRU_A10_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/PRU_A14_2017/slurm/slurm_PRU_A14_2017_LiDAR_grid_metrics.sh
# Submitted batch job 11983617
# Submitted job for PRU_A14_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/PRU_A26_2017/slurm/slurm_PRU_A26_2017_LiDAR_grid_metrics.sh
# Submitted batch job 11983618
# Submitted job for PRU_A26_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/SDM_A01_2017/slurm/slurm_SDM_A01_2017_laz_grid_metrics.sh
# Submitted batch job 11983619
# Submitted job for SDM_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2017/TAP_A01_2017/slurm/slurm_TAP_A01_2017_las_grid_metrics.sh
# Submitted batch job 11983620
# Submitted job for TAP_A01_2017
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/ANA_A01_2018/slurm/slurm_ANA_A01_2018_LAS_grid_metrics.sh
# Submitted batch job 11983621
# Submitted job for ANA_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/BON_A01_2018/slurm/slurm_BON_A01_2018_LAS_grid_metrics.sh
# Submitted batch job 11983622
# Submitted job for BON_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/FNA_A01_2018/slurm/slurm_FNA_A01_2018_LAS_grid_metrics.sh
# Submitted batch job 11983623
# Submitted job for FNA_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/FNE_A01_2018/slurm/slurm_FNE_A01_2018_LAS_grid_metrics.sh
# Submitted batch job 11983624
# Submitted job for FNE_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/HUM_A01_2018/slurm/slurm_HUM_A01_2018_LAS_grid_metrics.sh
# Submitted batch job 11983625
# Submitted job for HUM_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/RIB_A01_2018/slurm/slurm_RIB_A01_2018_LAS_grid_metrics.sh
# Submitted batch job 11983626
# Submitted job for RIB_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAL_A01_2018/slurm/slurm_TAL_A01_2018_LAS_grid_metrics.sh
# Submitted batch job 11983627
# Submitted job for TAL_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAN_A01_2018/slurm/slurm_TAN_A01_2018_LAS_grid_metrics.sh
# Submitted batch job 11983628
# Submitted job for TAN_A01_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAP_A02_2018/slurm/slurm_TAP_A02_2018_LAS_grid_metrics.sh
# Submitted batch job 11983629
# Submitted job for TAP_A02_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAP_A03_2018/slurm/slurm_TAP_A03_2018_LAS_grid_metrics.sh
# Submitted batch job 11983630
# Submitted job for TAP_A03_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAP_A04_2018/slurm/slurm_TAP_A04_2018_LAS_grid_metrics.sh
# Submitted batch job 11983631
# Submitted job for TAP_A04_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAP_A05_2018/slurm/slurm_TAP_A05_2018_LAS_grid_metrics.sh
# Submitted batch job 11983632
# Submitted job for TAP_A05_2018
# /work/scratch-nopw/forecol/Paisagenslidar/processed/2018/TAP_A06_2018/slurm/slurm_TAP_A06_2018_LAS_grid_metrics.sh
# Submitted batch job 11983633
# Submitted job for TAP_A06_2018

# %% [markdown]
# -----------

# %% [markdown]
# ## 2. EBA - Cluster normalisation

# %%
eba_meta_path = latest_matching_file(EBALIDAR_PATH / "*metadata")
eba_meta = gpd.read_file(eba_meta_path)

# %%
eba_laz = {path.name: {"path": path,
                       "name": path.name.split(".")[0],
                       "size": round(path.stat().st_size / 1024**2,2)
                      } 
           for path in (EBALIDAR_PATH / "laz_EBA").glob("*.laz")
          }

# %%
df = pd.DataFrame(eba_laz).T.convert_dtypes()
df = df.rename(columns={"size": "size (MB)"})
df["reduced_filename"] = df["name"] + ".laz"

# %%
eba_new_meta = pd.merge(eba_meta.drop(columns=["path", "size (MB)", "name"]), df, how="outer", on="reduced_filename")
eba_new_meta["size (MB)"] = eba_new_meta["size (MB)"].astype(float)
eba_new_meta.index = eba_new_meta["reduced_filename"]
eba_new_meta.index.name = "survey"
eba_new_meta = eba_new_meta.sort_index()
eba_new_meta
# Out:
#                       survey transect field_data hyperspect   obs  campaign  \
# survey
# NP_T-0001.laz  NP_T-0001.laz     0001       None       None  None       1.0
# NP_T-0002.laz  NP_T-0002.laz     0002       None       None  None       1.0
# NP_T-0003.laz  NP_T-0003.laz     0003       None       None  None       1.0
# NP_T-0004.laz  NP_T-0004.laz     0004       None       None  None       1.0
# NP_T-0005.laz  NP_T-0005.laz     0005       None       None  None       1.0
# ...                      ...      ...        ...        ...   ...       ...
# NP_T-2001.laz  NP_T-2001.laz     2001       None       None  None       2.0
# NP_T-2002.laz  NP_T-2002.laz     2002       None       None  None       2.0
# NP_T-2004.laz  NP_T-2004.laz     2004       None       None  None       2.0
# NP_T-2005.laz  NP_T-2005.laz     2005       None       None  None       2.0
# NP_T-2006.laz  NP_T-2006.laz     2006       None       None  None       2.0
#
#                         criteria                    datafile  elev_maxim  \
# survey
# NP_T-0001.laz  PRODES+TERRACLASS  NP_T-0001_dn_g_n_ch1_5.laz       38.12
# NP_T-0002.laz  PRODES+TERRACLASS  NP_T-0002_dn_g_n_ch1_5.laz       53.67
# NP_T-0003.laz  PRODES+TERRACLASS  NP_T-0003_dn_g_n_ch1_5.laz       72.00
# NP_T-0004.laz  PRODES+TERRACLASS  NP_T-0004_dn_g_n_ch1_5.laz       58.54
# NP_T-0005.laz  PRODES+TERRACLASS  NP_T-0005_dn_g_n_ch1_5.laz       62.72
# ...                          ...                         ...         ...
# NP_T-2001.laz           Directed  NP_T-2001_dn_g_n_ch1_5.laz       75.70
# NP_T-2002.laz           Directed  NP_T-2002_dn_g_n_ch1_5.laz       65.02
# NP_T-2004.laz           Directed  NP_T-2004_dn_g_n_ch1_5.laz       38.56
# NP_T-2005.laz           Directed  NP_T-2005_dn_g_n_ch1_5.laz       38.47
# NP_T-2006.laz           Directed  NP_T-2006_dn_g_n_ch1_5.laz       44.56
#
#                elev_mean  ...  canopy_rel  elev_sqrt_  elev_curt_  profile_ar  \
# survey                    ...
# NP_T-0001.laz    13.4278  ...    0.402270     14.9651     15.9663     50.9332
# NP_T-0002.laz    15.6308  ...    0.357771     18.2027     19.9904     41.2544
# NP_T-0003.laz    16.3030  ...    0.327655     18.6746     20.6112     37.3803
# NP_T-0004.laz    13.6670  ...    0.297323     16.5975     18.8821     33.5121
# NP_T-0005.laz    15.2655  ...    0.602625     17.4348     19.1750     38.3784
# ...                  ...  ...         ...         ...         ...         ...
# NP_T-2001.laz    19.9900  ...    0.544592     22.7049     24.3514     48.3164
# NP_T-2002.laz    21.2876  ...    0.451701     23.6641     25.3670     47.6701
# NP_T-2004.laz    13.5921  ...    0.445896     15.4306     16.6037     48.4385
# NP_T-2005.laz    13.9174  ...    0.504889     15.5562     16.6058     49.7625
# NP_T-2006.laz    13.1618  ...    0.336610     16.3947     18.1760     40.5686
#
#                random  reduced_filename  \
# survey
# NP_T-0001.laz     yes     NP_T-0001.laz
# NP_T-0002.laz     yes     NP_T-0002.laz
# NP_T-0003.laz     yes     NP_T-0003.laz
# NP_T-0004.laz     yes     NP_T-0004.laz
# NP_T-0005.laz     yes     NP_T-0005.laz
# ...               ...               ...
# NP_T-2001.laz      no     NP_T-2001.laz
# NP_T-2002.laz      no     NP_T-2002.laz
# NP_T-2004.laz      no     NP_T-2004.laz
# NP_T-2005.laz      no     NP_T-2005.laz
# NP_T-2006.laz      no     NP_T-2006.laz
#
#                                                         geometry  \
# survey
# NP_T-0001.laz  POLYGON ((4113515.087 10124216.741, 4113517.77...
# NP_T-0002.laz  POLYGON ((4051446.715 10275374.329, 4051471.18...
# NP_T-0003.laz  POLYGON ((4030556.091 10289424.141, 4030585.79...
# NP_T-0004.laz  POLYGON ((4117057.589 10328223.327, 4117057.60...
# NP_T-0005.laz  POLYGON ((4073980.272 10342069.880, 4073985.18...
# ...                                                          ...
# NP_T-2001.laz  POLYGON ((4687939.276 9807283.147, 4687940.579...
# NP_T-2002.laz  POLYGON ((4015043.537 8959928.665, 4015049.131...
# NP_T-2004.laz  POLYGON ((4965389.690 8676632.304, 4965375.149...
# NP_T-2005.laz  POLYGON ((4966156.783 8700836.900, 4966152.552...
# NP_T-2006.laz  POLYGON ((3994672.822 9124853.591, 3994673.027...
#
#                                                             path       name  \
# survey
# NP_T-0001.laz  /gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA/N...  NP_T-0001
# NP_T-0002.laz  /gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA/N...  NP_T-0002
# NP_T-0003.laz  /gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA/N...  NP_T-0003
# NP_T-0004.laz  /gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA/N...  NP_T-0004
# NP_T-0005.laz  /gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA/N...  NP_T-0005
# ...                                                          ...        ...
# NP_T-2001.laz  /gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA/N...  NP_T-2001
# NP_T-2002.laz  /gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA/N...  NP_T-2002
# NP_T-2004.laz  /gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA/N...  NP_T-2004
# NP_T-2005.laz  /gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA/N...  NP_T-2005
# NP_T-2006.laz  /gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA/N...  NP_T-2006
#
#                size (MB)
# survey
# NP_T-0001.laz     233.47
# NP_T-0002.laz     254.80
# NP_T-0003.laz     204.94
# NP_T-0004.laz     208.09
# NP_T-0005.laz     234.38
# ...                  ...
# NP_T-2001.laz     225.71
# NP_T-2002.laz     190.41
# NP_T-2004.laz     185.83
# NP_T-2005.laz     196.11
# NP_T-2006.laz     184.82
#
# [930 rows x 51 columns]

# %%
#eba_new_meta.to_file(eba_meta_path.parent / f"eba_file_metadata_v{datetime.date.today()}", driver="GPKG")

# %%
smallest = df.iloc[df["size (MB)"].values.argmin():df["size (MB)"].values.argmin()+1]
smallest
# Out:
#                                                                path  \
# NP_T-1041_03.laz  /gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA/N...
#
#                           name  size (MB)  reduced_filename
# NP_T-1041_03.laz  NP_T-1041_03      53.26  NP_T-1041_03.laz

# %% [markdown]
# ### Normalisation: Create slurm job

# %%
for idx, survey in tqdm(eba_new_meta.iterrows(), total=len(eba_new_meta)):
    
    if survey["path"] is None or pd.isna(survey["path"]):
        continue
    
    if os.getenv("USE_SCRATCH"):
        out_dir = SCRATCH_PATH / "EBA_lidar" / "laz_EBA_processed" / survey["name"]
    else:
        out_dir = EBALIDAR_PATH / "laz_EBA_processed" / survey["name"]
    
    if contains(out_dir, "processed") and not is_empty(out_dir / "processed"):
        continue
    #else:
        #print("Not processed:", survey["name"])
        #continue
    
    job_file = lidR_processing_job(lidar_path=survey.path,
                                   survey_name = survey.name,
                                   out_dir = out_dir,
                                   queue="short-serial",
                                   max_time = datetime.time(23, 59, 0),
                                   chunk_size=1000,
                                   buffer=50,
                                   filter_quantile = 0.95,
                                   filter_sensitivity = 1.1,
                                   filter_gridsize= 10,
                                   as_file=True, 
                                   perform_check=False,
                                   compress_intermediates=True, 
                                   required_memory_per_node=16000,
                                  )
    
    print(job_file)
    break
    # Submit job
    sbatch(job_file)
    print(f"Submitted job for {survey['name']}")
# Out:
#   0%|          | 0/930 [00:00<?, ?it/s]
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0001/slurm/slurm_NP_T-0001.laz.sh
# Submitted batch job 11984310
# Submitted job for NP_T-0001
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0002/slurm/slurm_NP_T-0002.laz.sh
# Submitted batch job 11984311
# Submitted job for NP_T-0002
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0003/slurm/slurm_NP_T-0003.laz.sh
# Submitted batch job 11984312
# Submitted job for NP_T-0003
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0004/slurm/slurm_NP_T-0004.laz.sh
# Submitted batch job 11984313
# Submitted job for NP_T-0004
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0005/slurm/slurm_NP_T-0005.laz.sh
# Submitted batch job 11984314
# Submitted job for NP_T-0005
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0006/slurm/slurm_NP_T-0006.laz.sh
# Submitted batch job 11984315
# Submitted job for NP_T-0006
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0007/slurm/slurm_NP_T-0007.laz.sh
# Submitted batch job 11984317
# Submitted job for NP_T-0007
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0008/slurm/slurm_NP_T-0008.laz.sh
# Submitted batch job 11984319
# Submitted job for NP_T-0008
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0009/slurm/slurm_NP_T-0009.laz.sh
# Submitted batch job 11984322
# Submitted job for NP_T-0009
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0010/slurm/slurm_NP_T-0010.laz.sh
# Submitted batch job 11984324
# Submitted job for NP_T-0010
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0011/slurm/slurm_NP_T-0011.laz.sh
# Submitted batch job 11984325
# Submitted job for NP_T-0011
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0012/slurm/slurm_NP_T-0012.laz.sh
# Submitted batch job 11984330
# Submitted job for NP_T-0012
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0013/slurm/slurm_NP_T-0013.laz.sh
# Submitted job for NP_T-0013
# Submitted batch job 11984331
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0014/slurm/slurm_NP_T-0014.laz.sh
# Submitted batch job 11984336
# Submitted job for NP_T-0014
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0015/slurm/slurm_NP_T-0015.laz.sh
# Submitted batch job 11984342
# Submitted job for NP_T-0015
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0016/slurm/slurm_NP_T-0016.laz.sh
# Submitted batch job 11984343
# Submitted job for NP_T-0016
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0017/slurm/slurm_NP_T-0017.laz.sh
# Submitted batch job 11984345
# Submitted job for NP_T-0017
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0018/slurm/slurm_NP_T-0018.laz.sh
# Submitted batch job 11984350
# Submitted job for NP_T-0018
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0019/slurm/slurm_NP_T-0019.laz.sh
# Submitted batch job 11984352
# Submitted job for NP_T-0019
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-001B/slurm/slurm_NP_T-001B.laz.sh
# Submitted batch job 11984354
# Submitted job for NP_T-001B
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0020/slurm/slurm_NP_T-0020.laz.sh
# Submitted batch job 11984360
# Submitted job for NP_T-0020
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0021/slurm/slurm_NP_T-0021.laz.sh
# Submitted batch job 11984362
# Submitted job for NP_T-0021
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0022/slurm/slurm_NP_T-0022.laz.sh
# Submitted batch job 11984363
# Submitted job for NP_T-0022
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0023/slurm/slurm_NP_T-0023.laz.sh
# Submitted batch job 11984364
# Submitted job for NP_T-0023
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0024/slurm/slurm_NP_T-0024.laz.sh
# Submitted batch job 11984373
# Submitted job for NP_T-0024
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0025/slurm/slurm_NP_T-0025.laz.sh
# Submitted batch job 11984376
# Submitted job for NP_T-0025
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0026/slurm/slurm_NP_T-0026.laz.sh
# Submitted batch job 11984382
# Submitted job for NP_T-0026
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0027/slurm/slurm_NP_T-0027.laz.sh
# Submitted batch job 11984384
# Submitted job for NP_T-0027
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0028/slurm/slurm_NP_T-0028.laz.sh
# Submitted batch job 11984385
# Submitted job for NP_T-0028
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0029/slurm/slurm_NP_T-0029.laz.sh
# Submitted job for NP_T-0029Submitted batch job 11984387
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0030/slurm/slurm_NP_T-0030.laz.sh
# Submitted batch job 11984389
# Submitted job for NP_T-0030
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0031/slurm/slurm_NP_T-0031.laz.sh
# Submitted batch job 11984392
# Submitted job for NP_T-0031
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0032/slurm/slurm_NP_T-0032.laz.sh
# Submitted batch job 11984398
# Submitted job for NP_T-0032
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0033/slurm/slurm_NP_T-0033.laz.sh
# Submitted batch job 11984403
# Submitted job for NP_T-0033
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0034/slurm/slurm_NP_T-0034.laz.sh
# Submitted batch job 11984406
# Submitted job for NP_T-0034
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0035/slurm/slurm_NP_T-0035.laz.sh
# Submitted batch job 11984411
# Submitted job for NP_T-0035
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0036/slurm/slurm_NP_T-0036.laz.sh
# Submitted batch job 11984414
# Submitted job for NP_T-0036
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0037/slurm/slurm_NP_T-0037.laz.sh
# Submitted batch job 11984415
# Submitted job for NP_T-0037
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0038/slurm/slurm_NP_T-0038.laz.sh
# Submitted batch job 11984416
# Submitted job for NP_T-0038
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0039/slurm/slurm_NP_T-0039.laz.sh
# Submitted batch job 11984419
# Submitted job for NP_T-0039
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0040/slurm/slurm_NP_T-0040.laz.sh
# Submitted batch job 11984422
# Submitted job for NP_T-0040
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0041/slurm/slurm_NP_T-0041.laz.sh
# Submitted batch job 11984426
# Submitted job for NP_T-0041
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0042/slurm/slurm_NP_T-0042.laz.sh
# Submitted batch job 11984431
# Submitted job for NP_T-0042
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0043/slurm/slurm_NP_T-0043.laz.sh
# Submitted batch job 11984432
# Submitted job for NP_T-0043
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0044/slurm/slurm_NP_T-0044.laz.sh
# Submitted batch job 11984433
# Submitted job for NP_T-0044
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0045/slurm/slurm_NP_T-0045.laz.sh
# Submitted batch job 11984434
# Submitted job for NP_T-0045
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0046/slurm/slurm_NP_T-0046.laz.sh
# Submitted job for NP_T-0046Submitted batch job 11984435
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0047/slurm/slurm_NP_T-0047.laz.sh
# Submitted batch job 11984443
# Submitted job for NP_T-0047
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0048/slurm/slurm_NP_T-0048.laz.sh
# Submitted batch job 11984448
# Submitted job for NP_T-0048
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0049/slurm/slurm_NP_T-0049.laz.sh
# Submitted batch job 11984455
# Submitted job for NP_T-0049
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0050/slurm/slurm_NP_T-0050.laz.sh
# Submitted batch job 11984456
# Submitted job for NP_T-0050
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0051/slurm/slurm_NP_T-0051.laz.sh
# Submitted batch job 11984457
# Submitted job for NP_T-0051
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0052/slurm/slurm_NP_T-0052.laz.sh
# Submitted batch job 11984458
# Submitted job for NP_T-0052
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0053/slurm/slurm_NP_T-0053.laz.sh
# Submitted batch job 11984459
# Submitted job for NP_T-0053
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0054/slurm/slurm_NP_T-0054.laz.sh
# Submitted batch job 11984461
# Submitted job for NP_T-0054
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0055/slurm/slurm_NP_T-0055.laz.sh
# Submitted batch job 11984462
# Submitted job for NP_T-0055
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0056/slurm/slurm_NP_T-0056.laz.sh
# Submitted batch job 11984463
# Submitted job for NP_T-0056
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0057/slurm/slurm_NP_T-0057.laz.sh
# Submitted batch job 11984464
# Submitted job for NP_T-0057
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0058/slurm/slurm_NP_T-0058.laz.sh
# Submitted batch job 11984465
# Submitted job for NP_T-0058
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0060/slurm/slurm_NP_T-0060.laz.sh
# Submitted batch job 11984466
# Submitted job for NP_T-0060
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0061/slurm/slurm_NP_T-0061.laz.sh
# Submitted batch job 11984468
# Submitted job for NP_T-0061
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0062/slurm/slurm_NP_T-0062.laz.sh
# Submitted batch job 11984471
# Submitted job for NP_T-0062
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0063/slurm/slurm_NP_T-0063.laz.sh
# Submitted batch job 11984475
# Submitted job for NP_T-0063
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0064/slurm/slurm_NP_T-0064.laz.sh
# Submitted batch job 11984476
# Submitted job for NP_T-0064
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0065/slurm/slurm_NP_T-0065.laz.sh
# Submitted batch job 11984477
# Submitted job for NP_T-0065
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0066/slurm/slurm_NP_T-0066.laz.sh
# Submitted batch job 11984479
# Submitted job for NP_T-0066
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0067/slurm/slurm_NP_T-0067.laz.sh
# Submitted batch job 11984480
# Submitted job for NP_T-0067
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0068/slurm/slurm_NP_T-0068.laz.sh
# Submitted batch job 11984481
# Submitted job for NP_T-0068
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0069/slurm/slurm_NP_T-0069.laz.sh
# Submitted batch job 11984482
# Submitted job for NP_T-0069
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0070/slurm/slurm_NP_T-0070.laz.sh
# Submitted batch job 11984484
# Submitted job for NP_T-0070
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0071/slurm/slurm_NP_T-0071.laz.sh
# Submitted batch job 11984488
# Submitted job for NP_T-0071
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0072/slurm/slurm_NP_T-0072.laz.sh
# Submitted batch job 11984489
# Submitted job for NP_T-0072
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0073/slurm/slurm_NP_T-0073.laz.sh
# Submitted batch job 11984490
# Submitted job for NP_T-0073
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0074/slurm/slurm_NP_T-0074.laz.sh
# Submitted batch job 11984491
# Submitted job for NP_T-0074
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0075/slurm/slurm_NP_T-0075.laz.sh
# Submitted batch job 11984492
# Submitted job for NP_T-0075
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0076/slurm/slurm_NP_T-0076.laz.sh
# Submitted batch job 11984494
# Submitted job for NP_T-0076
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0077/slurm/slurm_NP_T-0077.laz.sh
# Submitted batch job 11984498
# Submitted job for NP_T-0077
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0078/slurm/slurm_NP_T-0078.laz.sh
# Submitted batch job 11984499
# Submitted job for NP_T-0078
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0079/slurm/slurm_NP_T-0079.laz.sh
# Submitted batch job 11984503
# Submitted job for NP_T-0079
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-007B/slurm/slurm_NP_T-007B.laz.sh
# Submitted batch job 11984504
# Submitted job for NP_T-007B
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0080/slurm/slurm_NP_T-0080.laz.sh
# Submitted batch job 11984505
# Submitted job for NP_T-0080
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0081/slurm/slurm_NP_T-0081.laz.sh
# Submitted batch job 11984506
# Submitted job for NP_T-0081
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0082/slurm/slurm_NP_T-0082.laz.sh
# Submitted batch job 11984507
# Submitted job for NP_T-0082
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0083/slurm/slurm_NP_T-0083.laz.sh
# Submitted batch job 11984510
# Submitted job for NP_T-0083
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0084/slurm/slurm_NP_T-0084.laz.sh
# Submitted batch job 11984513
# Submitted job for NP_T-0084
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0085/slurm/slurm_NP_T-0085.laz.sh
# Submitted batch job 11984517
# Submitted job for NP_T-0085
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0086/slurm/slurm_NP_T-0086.laz.sh
# Submitted batch job 11984519
# Submitted job for NP_T-0086
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0087/slurm/slurm_NP_T-0087.laz.sh
# Submitted batch job 11984520
# Submitted job for NP_T-0087
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0088/slurm/slurm_NP_T-0088.laz.sh
# Submitted batch job 11984521
# Submitted job for NP_T-0088
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0089/slurm/slurm_NP_T-0089.laz.sh
# Submitted job for NP_T-0089
# Submitted batch job 11984523
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0090/slurm/slurm_NP_T-0090.laz.sh
# Submitted batch job 11984524
# Submitted job for NP_T-0090
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0091/slurm/slurm_NP_T-0091.laz.sh
# Submitted batch job 11984525
# Submitted job for NP_T-0091
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0092/slurm/slurm_NP_T-0092.laz.sh
# Submitted batch job 11984529
# Submitted job for NP_T-0092
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0093/slurm/slurm_NP_T-0093.laz.sh
# Submitted batch job 11984530
# Submitted job for NP_T-0093
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0094/slurm/slurm_NP_T-0094.laz.sh
# Submitted batch job 11984531
# Submitted job for NP_T-0094
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0095/slurm/slurm_NP_T-0095.laz.sh
# Submitted batch job 11984532
# Submitted job for NP_T-0095
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0096/slurm/slurm_NP_T-0096.laz.sh
# Submitted batch job 11984533
# Submitted job for NP_T-0096
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0097/slurm/slurm_NP_T-0097.laz.sh
# Submitted batch job 11984537
# Submitted job for NP_T-0097
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0098/slurm/slurm_NP_T-0098.laz.sh
# Submitted batch job 11984538
# Submitted job for NP_T-0098
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0099/slurm/slurm_NP_T-0099.laz.sh
# Submitted batch job 11984539
# Submitted job for NP_T-0099
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0100/slurm/slurm_NP_T-0100.laz.sh
# Submitted batch job 11984540
# Submitted job for NP_T-0100
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0101/slurm/slurm_NP_T-0101.laz.sh
# Submitted batch job 11984541
# Submitted job for NP_T-0101
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0102/slurm/slurm_NP_T-0102.laz.sh
# Submitted batch job 11984542
# Submitted job for NP_T-0102
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0103/slurm/slurm_NP_T-0103.laz.sh
# Submitted batch job 11984543
# Submitted job for NP_T-0103
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0104/slurm/slurm_NP_T-0104.laz.sh
# Submitted job for NP_T-0104Submitted batch job 11984544
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0105/slurm/slurm_NP_T-0105.laz.sh
# Submitted batch job 11984550
# Submitted job for NP_T-0105
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0106/slurm/slurm_NP_T-0106.laz.sh
# Submitted batch job 11984554
# Submitted job for NP_T-0106
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0107/slurm/slurm_NP_T-0107.laz.sh
# Submitted batch job 11984558
# Submitted job for NP_T-0107
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0108/slurm/slurm_NP_T-0108.laz.sh
# Submitted batch job 11984561
# Submitted job for NP_T-0108
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0109/slurm/slurm_NP_T-0109.laz.sh
# Submitted batch job 11984565
# Submitted job for NP_T-0109
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0110/slurm/slurm_NP_T-0110.laz.sh
# Submitted batch job 11984576
# Submitted job for NP_T-0110
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0111/slurm/slurm_NP_T-0111.laz.sh
# Submitted job for NP_T-0111
# Submitted batch job 11984609
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0112/slurm/slurm_NP_T-0112.laz.sh
# Submitted job for NP_T-0112Submitted batch job 11984616
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0113/slurm/slurm_NP_T-0113.laz.sh
# Submitted batch job 11984618
# Submitted job for NP_T-0113
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0114/slurm/slurm_NP_T-0114.laz.sh
# Submitted batch job 11984620
# Submitted job for NP_T-0114
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0115/slurm/slurm_NP_T-0115.laz.sh
# Submitted batch job 11984623
# Submitted job for NP_T-0115
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0116/slurm/slurm_NP_T-0116.laz.sh
# Submitted batch job 11984627
# Submitted job for NP_T-0116
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0118/slurm/slurm_NP_T-0118.laz.sh
# Submitted batch job 11984631
# Submitted job for NP_T-0118
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0120/slurm/slurm_NP_T-0120.laz.sh
# Submitted batch job 11984635
# Submitted job for NP_T-0120
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0121/slurm/slurm_NP_T-0121.laz.sh
# Submitted batch job 11984639
# Submitted job for NP_T-0121
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0122/slurm/slurm_NP_T-0122.laz.sh
# Submitted batch job 11984644
# Submitted job for NP_T-0122
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0123/slurm/slurm_NP_T-0123.laz.sh
# Submitted batch job 11984645
# Submitted job for NP_T-0123
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0124/slurm/slurm_NP_T-0124.laz.sh
# Submitted batch job 11984646
# Submitted job for NP_T-0124
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0125/slurm/slurm_NP_T-0125.laz.sh
# Submitted batch job 11984647
# Submitted job for NP_T-0125
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0126/slurm/slurm_NP_T-0126.laz.sh
# Submitted batch job 11984648
# Submitted job for NP_T-0126
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0127/slurm/slurm_NP_T-0127.laz.sh
# Submitted batch job 11984649
# Submitted job for NP_T-0127
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0128/slurm/slurm_NP_T-0128.laz.sh
# Submitted batch job 11984650
# Submitted job for NP_T-0128
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0129/slurm/slurm_NP_T-0129.laz.sh
# Submitted batch job 11984651
# Submitted job for NP_T-0129
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0130/slurm/slurm_NP_T-0130.laz.sh
# Submitted batch job 11984652
# Submitted job for NP_T-0130
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0131/slurm/slurm_NP_T-0131.laz.sh
# Submitted batch job 11984653
# Submitted job for NP_T-0131
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0132/slurm/slurm_NP_T-0132.laz.sh
# Submitted batch job 11984654
# Submitted job for NP_T-0132
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0133/slurm/slurm_NP_T-0133.laz.sh
# Submitted batch job 11984656
# Submitted job for NP_T-0133
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0134/slurm/slurm_NP_T-0134.laz.sh
# Submitted batch job 11984662
# Submitted job for NP_T-0134
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0135/slurm/slurm_NP_T-0135.laz.sh
# Submitted batch job 11984663
# Submitted job for NP_T-0135
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0136/slurm/slurm_NP_T-0136.laz.sh
# Submitted batch job 11984664
# Submitted job for NP_T-0136
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0137/slurm/slurm_NP_T-0137.laz.sh
# Submitted batch job 11984666
# Submitted job for NP_T-0137
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0138/slurm/slurm_NP_T-0138.laz.sh
# Submitted batch job 11984667
# Submitted job for NP_T-0138
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0139/slurm/slurm_NP_T-0139.laz.sh
# Submitted batch job 11984668
# Submitted job for NP_T-0139
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0140/slurm/slurm_NP_T-0140.laz.sh
# Submitted batch job 11984669
# Submitted job for NP_T-0140
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0141/slurm/slurm_NP_T-0141.laz.sh
# Submitted batch job 11984670
# Submitted job for NP_T-0141
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0142/slurm/slurm_NP_T-0142.laz.sh
# Submitted batch job 11984671
# Submitted job for NP_T-0142
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0143/slurm/slurm_NP_T-0143.laz.sh
# Submitted batch job 11984676
# Submitted job for NP_T-0143
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0144/slurm/slurm_NP_T-0144.laz.sh
# Submitted batch job 11984679
# Submitted job for NP_T-0144
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0145/slurm/slurm_NP_T-0145.laz.sh
# Submitted job for NP_T-0145Submitted batch job 11984680
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0146/slurm/slurm_NP_T-0146.laz.sh
# Submitted batch job 11984681
# Submitted job for NP_T-0146
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0147/slurm/slurm_NP_T-0147.laz.sh
# Submitted batch job 11984682
# Submitted job for NP_T-0147
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0148/slurm/slurm_NP_T-0148.laz.sh
# Submitted job for NP_T-0148
# Submitted batch job 11984683
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0149/slurm/slurm_NP_T-0149.laz.sh
# Submitted job for NP_T-0149
# Submitted batch job 11984684
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0150/slurm/slurm_NP_T-0150.laz.sh
# Submitted batch job 11984685
# Submitted job for NP_T-0150
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0151/slurm/slurm_NP_T-0151.laz.sh
# Submitted batch job 11984686
# Submitted job for NP_T-0151
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0152/slurm/slurm_NP_T-0152.laz.sh
# Submitted batch job 11984687
# Submitted job for NP_T-0152
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0153/slurm/slurm_NP_T-0153.laz.sh
# Submitted batch job 11984688
# Submitted job for NP_T-0153
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0154/slurm/slurm_NP_T-0154.laz.sh
# Submitted batch job 11984689
# Submitted job for NP_T-0154
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0155/slurm/slurm_NP_T-0155.laz.sh
# Submitted batch job 11984693
# Submitted job for NP_T-0155
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0156/slurm/slurm_NP_T-0156.laz.sh
# Submitted batch job 11984695
# Submitted job for NP_T-0156
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0157/slurm/slurm_NP_T-0157.laz.sh
# Submitted batch job 11984696
# Submitted job for NP_T-0157
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0158/slurm/slurm_NP_T-0158.laz.sh
# Submitted job for NP_T-0158Submitted batch job 11984699
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0159/slurm/slurm_NP_T-0159.laz.sh
# Submitted batch job 11984700
# Submitted job for NP_T-0159
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0160/slurm/slurm_NP_T-0160.laz.sh
# Submitted batch job 11984701
# Submitted job for NP_T-0160
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0161/slurm/slurm_NP_T-0161.laz.sh
# Submitted batch job 11984702
# Submitted job for NP_T-0161
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0162/slurm/slurm_NP_T-0162.laz.sh
# Submitted batch job 11984703
# Submitted job for NP_T-0162
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0163/slurm/slurm_NP_T-0163.laz.sh
# Submitted batch job 11984705
# Submitted job for NP_T-0163
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0164/slurm/slurm_NP_T-0164.laz.sh
# Submitted batch job 11984710
# Submitted job for NP_T-0164
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0165/slurm/slurm_NP_T-0165.laz.sh
# Submitted batch job 11984711
# Submitted job for NP_T-0165
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0166/slurm/slurm_NP_T-0166.laz.sh
# Submitted batch job 11984712
# Submitted job for NP_T-0166
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0167/slurm/slurm_NP_T-0167.laz.sh
# Submitted batch job 11984718
# Submitted job for NP_T-0167
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0168/slurm/slurm_NP_T-0168.laz.sh
# Submitted batch job 11984720
# Submitted job for NP_T-0168
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0169/slurm/slurm_NP_T-0169.laz.sh
# Submitted batch job 11984724
# Submitted job for NP_T-0169
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0170/slurm/slurm_NP_T-0170.laz.sh
# Submitted batch job 11984727
# Submitted job for NP_T-0170
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0171/slurm/slurm_NP_T-0171.laz.sh
# Submitted batch job 11984729
# Submitted job for NP_T-0171
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0172/slurm/slurm_NP_T-0172.laz.sh
# Submitted batch job 11984735
# Submitted job for NP_T-0172
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0173/slurm/slurm_NP_T-0173.laz.sh
# Submitted batch job 11984736
# Submitted job for NP_T-0173
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0174/slurm/slurm_NP_T-0174.laz.sh
# Submitted batch job 11984737
# Submitted job for NP_T-0174
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0175/slurm/slurm_NP_T-0175.laz.sh
# Submitted batch job 11984738
# Submitted job for NP_T-0175
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0176/slurm/slurm_NP_T-0176.laz.sh
# Submitted batch job 11984739
# Submitted job for NP_T-0176
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0177/slurm/slurm_NP_T-0177.laz.sh
# Submitted batch job 11984740
# Submitted job for NP_T-0177
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0178/slurm/slurm_NP_T-0178.laz.sh
# Submitted batch job 11984745
# Submitted job for NP_T-0178
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0179/slurm/slurm_NP_T-0179.laz.sh
# Submitted batch job 11984747
# Submitted job for NP_T-0179
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0180/slurm/slurm_NP_T-0180.laz.sh
# Submitted batch job 11984752
# Submitted job for NP_T-0180
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0181/slurm/slurm_NP_T-0181.laz.sh
# Submitted batch job 11984753
# Submitted job for NP_T-0181
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0183/slurm/slurm_NP_T-0183.laz.sh
# Submitted batch job 11984756
# Submitted job for NP_T-0183
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0184/slurm/slurm_NP_T-0184.laz.sh
# Submitted batch job 11984757
# Submitted job for NP_T-0184
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0185/slurm/slurm_NP_T-0185.laz.sh
# Submitted batch job 11984761
# Submitted job for NP_T-0185
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0186/slurm/slurm_NP_T-0186.laz.sh
# Submitted batch job 11984765
# Submitted job for NP_T-0186
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0187/slurm/slurm_NP_T-0187.laz.sh
# Submitted batch job 11984768
# Submitted job for NP_T-0187
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0188/slurm/slurm_NP_T-0188.laz.sh
# Submitted batch job 11984770
# Submitted job for NP_T-0188
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0189/slurm/slurm_NP_T-0189.laz.sh
# Submitted batch job 11984771
# Submitted job for NP_T-0189
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0190/slurm/slurm_NP_T-0190.laz.sh
# Submitted batch job 11984779
# Submitted job for NP_T-0190
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0191/slurm/slurm_NP_T-0191.laz.sh
# Submitted batch job 11984780
# Submitted job for NP_T-0191
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0192/slurm/slurm_NP_T-0192.laz.sh
# Submitted batch job 11984798
# Submitted job for NP_T-0192
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0193/slurm/slurm_NP_T-0193.laz.sh
# Submitted batch job 11984801
# Submitted job for NP_T-0193
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0194/slurm/slurm_NP_T-0194.laz.sh
# Submitted batch job 11984802
# Submitted job for NP_T-0194
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0195/slurm/slurm_NP_T-0195.laz.sh
# Submitted batch job 11984803
# Submitted job for NP_T-0195
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0196/slurm/slurm_NP_T-0196.laz.sh
# Submitted batch job 11984808
# Submitted job for NP_T-0196
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0197/slurm/slurm_NP_T-0197.laz.sh
# Submitted batch job 11984809
# Submitted job for NP_T-0197
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0198/slurm/slurm_NP_T-0198.laz.sh
# Submitted batch job 11984815
# Submitted job for NP_T-0198
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0199/slurm/slurm_NP_T-0199.laz.sh
# Submitted batch job 11984816
# Submitted job for NP_T-0199
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0200/slurm/slurm_NP_T-0200.laz.sh
# Submitted batch job 11984819
# Submitted job for NP_T-0200
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0201/slurm/slurm_NP_T-0201.laz.sh
# Submitted batch job 11984822
# Submitted job for NP_T-0201
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0202/slurm/slurm_NP_T-0202.laz.sh
# Submitted batch job 11984823
# Submitted job for NP_T-0202
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0203/slurm/slurm_NP_T-0203.laz.sh
# Submitted job for NP_T-0203Submitted batch job 11984824
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0204/slurm/slurm_NP_T-0204.laz.sh
# Submitted batch job 11984828
# Submitted job for NP_T-0204
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0205/slurm/slurm_NP_T-0205.laz.sh
# Submitted batch job 11984832
# Submitted job for NP_T-0205
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0206/slurm/slurm_NP_T-0206.laz.sh
# Submitted batch job 11984835
# Submitted job for NP_T-0206
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0208/slurm/slurm_NP_T-0208.laz.sh
# Submitted batch job 11984837
# Submitted job for NP_T-0208
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0209/slurm/slurm_NP_T-0209.laz.sh
# Submitted batch job 11984841
# Submitted job for NP_T-0209
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0210/slurm/slurm_NP_T-0210.laz.sh
# Submitted batch job 11984844
# Submitted job for NP_T-0210
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0211/slurm/slurm_NP_T-0211.laz.sh
# Submitted batch job 11984845
# Submitted job for NP_T-0211
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0212/slurm/slurm_NP_T-0212.laz.sh
# Submitted batch job 11984851
# Submitted job for NP_T-0212
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0213/slurm/slurm_NP_T-0213.laz.sh
# Submitted batch job 11984858
# Submitted job for NP_T-0213
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0214/slurm/slurm_NP_T-0214.laz.sh
# Submitted batch job 11984861
# Submitted job for NP_T-0214
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0215/slurm/slurm_NP_T-0215.laz.sh
# Submitted batch job 11984864
# Submitted job for NP_T-0215
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0216/slurm/slurm_NP_T-0216.laz.sh
# Submitted batch job 11984866
# Submitted job for NP_T-0216
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0217/slurm/slurm_NP_T-0217.laz.sh
# Submitted batch job 11984869
# Submitted job for NP_T-0217
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0218/slurm/slurm_NP_T-0218.laz.sh
# Submitted batch job 11984872
# Submitted job for NP_T-0218
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0219/slurm/slurm_NP_T-0219.laz.sh
# Submitted batch job 11984874
# Submitted job for NP_T-0219
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0220/slurm/slurm_NP_T-0220.laz.sh
# Submitted batch job 11984877
# Submitted job for NP_T-0220
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0221/slurm/slurm_NP_T-0221.laz.sh
# Submitted batch job 11984885
# Submitted job for NP_T-0221
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0222/slurm/slurm_NP_T-0222.laz.sh
# Submitted job for NP_T-0222Submitted batch job 11984889
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0223/slurm/slurm_NP_T-0223.laz.sh
# Submitted batch job 11984896
# Submitted job for NP_T-0223
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0224/slurm/slurm_NP_T-0224.laz.sh
# Submitted batch job 11984900
# Submitted job for NP_T-0224
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0225/slurm/slurm_NP_T-0225.laz.sh
# Submitted batch job 11984906
# Submitted job for NP_T-0225
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0226/slurm/slurm_NP_T-0226.laz.sh
# Submitted batch job 11984908
# Submitted job for NP_T-0226
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0227/slurm/slurm_NP_T-0227.laz.sh
# Submitted job for NP_T-0227
# Submitted batch job 11984928
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0228/slurm/slurm_NP_T-0228.laz.sh
# Submitted batch job 11984934
# Submitted job for NP_T-0228
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0229/slurm/slurm_NP_T-0229.laz.sh
# Submitted batch job 11984948
# Submitted job for NP_T-0229
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0230/slurm/slurm_NP_T-0230.laz.sh
# Submitted batch job 11984960
# Submitted job for NP_T-0230
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0231/slurm/slurm_NP_T-0231.laz.sh
# Submitted batch job 11984966
# Submitted job for NP_T-0231
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0232/slurm/slurm_NP_T-0232.laz.sh
# Submitted batch job 11984969
# Submitted job for NP_T-0232
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0233/slurm/slurm_NP_T-0233.laz.sh
# Submitted batch job 11984972
# Submitted job for NP_T-0233
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0234/slurm/slurm_NP_T-0234.laz.sh
# Submitted batch job 11984980
# Submitted job for NP_T-0234
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0235/slurm/slurm_NP_T-0235.laz.sh
# Submitted batch job 11984985
# Submitted job for NP_T-0235
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0236/slurm/slurm_NP_T-0236.laz.sh
# Submitted batch job 11984988
# Submitted job for NP_T-0236
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0237/slurm/slurm_NP_T-0237.laz.sh
# Submitted batch job 11984992
# Submitted job for NP_T-0237
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0238/slurm/slurm_NP_T-0238.laz.sh
# Submitted batch job 11984996
# Submitted job for NP_T-0238
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0239/slurm/slurm_NP_T-0239.laz.sh
# Submitted batch job 11984999
# Submitted job for NP_T-0239
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0240/slurm/slurm_NP_T-0240.laz.sh
# Submitted job for NP_T-0240Submitted batch job 11985001
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0241/slurm/slurm_NP_T-0241.laz.sh
# Submitted batch job 11985004
# Submitted job for NP_T-0241
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0242/slurm/slurm_NP_T-0242.laz.sh
# Submitted batch job 11985007
# Submitted job for NP_T-0242
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0243/slurm/slurm_NP_T-0243.laz.sh
# Submitted batch job 11985010
# Submitted job for NP_T-0243
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0244/slurm/slurm_NP_T-0244.laz.sh
# Submitted job for NP_T-0244
# Submitted batch job 11985013
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0245/slurm/slurm_NP_T-0245.laz.sh
# Submitted batch job 11985016
# Submitted job for NP_T-0245
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0246/slurm/slurm_NP_T-0246.laz.sh
# Submitted batch job 11985027
# Submitted job for NP_T-0246
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0247/slurm/slurm_NP_T-0247.laz.sh
# Submitted batch job 11985030
# Submitted job for NP_T-0247
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0248/slurm/slurm_NP_T-0248.laz.sh
# Submitted batch job 11985033
# Submitted job for NP_T-0248
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0249/slurm/slurm_NP_T-0249.laz.sh
# Submitted batch job 11985036
# Submitted job for NP_T-0249
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0250/slurm/slurm_NP_T-0250.laz.sh
# Submitted batch job 11985040
# Submitted job for NP_T-0250
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0251/slurm/slurm_NP_T-0251.laz.sh
# Submitted batch job 11985047
# Submitted job for NP_T-0251
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0252/slurm/slurm_NP_T-0252.laz.sh
# Submitted batch job 11985049
# Submitted job for NP_T-0252
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0253/slurm/slurm_NP_T-0253.laz.sh
# Submitted batch job 11985051
# Submitted job for NP_T-0253
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0254/slurm/slurm_NP_T-0254.laz.sh
# Submitted batch job 11985056
# Submitted job for NP_T-0254
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0255/slurm/slurm_NP_T-0255.laz.sh
# Submitted batch job 11985061
# Submitted job for NP_T-0255
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0256/slurm/slurm_NP_T-0256.laz.sh
# Submitted batch job 11985068
# Submitted job for NP_T-0256
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0257/slurm/slurm_NP_T-0257.laz.sh
# Submitted batch job 11985071
# Submitted job for NP_T-0257
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0258/slurm/slurm_NP_T-0258.laz.sh
# Submitted batch job 11985099
# Submitted job for NP_T-0258
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0259/slurm/slurm_NP_T-0259.laz.sh
# Submitted batch job 11985102
# Submitted job for NP_T-0259
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0260/slurm/slurm_NP_T-0260.laz.sh
# Submitted batch job 11985110
# Submitted job for NP_T-0260
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0261/slurm/slurm_NP_T-0261.laz.sh
# Submitted batch job 11985114
# Submitted job for NP_T-0261
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0262/slurm/slurm_NP_T-0262.laz.sh
# Submitted batch job 11985117
# Submitted job for NP_T-0262
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0263/slurm/slurm_NP_T-0263.laz.sh
# Submitted batch job 11985120
# Submitted job for NP_T-0263
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0264/slurm/slurm_NP_T-0264.laz.sh
# Submitted batch job 11985122
# Submitted job for NP_T-0264
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0265/slurm/slurm_NP_T-0265.laz.sh
# Submitted job for NP_T-0265Submitted batch job 11985124
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0266/slurm/slurm_NP_T-0266.laz.sh
# Submitted job for NP_T-0266Submitted batch job 11985126
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0267/slurm/slurm_NP_T-0267.laz.sh
# Submitted batch job 11985130
# Submitted job for NP_T-0267
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0268/slurm/slurm_NP_T-0268.laz.sh
# Submitted batch job 11985135
# Submitted job for NP_T-0268
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0269/slurm/slurm_NP_T-0269.laz.sh
# Submitted batch job 11985138
# Submitted job for NP_T-0269
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0271/slurm/slurm_NP_T-0271.laz.sh
# Submitted batch job 11985145
# Submitted job for NP_T-0271
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0272/slurm/slurm_NP_T-0272.laz.sh
# Submitted batch job 11985149
# Submitted job for NP_T-0272
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0273/slurm/slurm_NP_T-0273.laz.sh
# Submitted batch job 11985152
# Submitted job for NP_T-0273
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0274/slurm/slurm_NP_T-0274.laz.sh
# Submitted batch job 11985156
# Submitted job for NP_T-0274
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0275/slurm/slurm_NP_T-0275.laz.sh
# Submitted batch job 11985160
# Submitted job for NP_T-0275
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0276/slurm/slurm_NP_T-0276.laz.sh
# Submitted batch job 11985165
# Submitted job for NP_T-0276
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0277/slurm/slurm_NP_T-0277.laz.sh
# Submitted batch job 11985172
# Submitted job for NP_T-0277
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0278/slurm/slurm_NP_T-0278.laz.sh
# Submitted batch job 11985184
# Submitted job for NP_T-0278
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0279/slurm/slurm_NP_T-0279.laz.sh
# Submitted batch job 11985188
# Submitted job for NP_T-0279
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0280/slurm/slurm_NP_T-0280.laz.sh
# Submitted batch job 11985191
# Submitted job for NP_T-0280
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0281/slurm/slurm_NP_T-0281.laz.sh
# Submitted batch job 11985196
# Submitted job for NP_T-0281
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0282/slurm/slurm_NP_T-0282.laz.sh
# Submitted batch job 11985203
# Submitted job for NP_T-0282
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0283/slurm/slurm_NP_T-0283.laz.sh
# Submitted batch job 11985207
# Submitted job for NP_T-0283
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0284/slurm/slurm_NP_T-0284.laz.sh
# Submitted batch job 11985211
# Submitted job for NP_T-0284
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0285/slurm/slurm_NP_T-0285.laz.sh
# Submitted batch job 11985215
# Submitted job for NP_T-0285
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0286/slurm/slurm_NP_T-0286.laz.sh
# Submitted batch job 11985219
# Submitted job for NP_T-0286
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0287/slurm/slurm_NP_T-0287.laz.sh
# Submitted batch job 11985223
# Submitted job for NP_T-0287
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0288/slurm/slurm_NP_T-0288.laz.sh
# Submitted batch job 11985226
# Submitted job for NP_T-0288
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0289/slurm/slurm_NP_T-0289.laz.sh
# Submitted batch job 11985233
# Submitted job for NP_T-0289
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0290/slurm/slurm_NP_T-0290.laz.sh
# Submitted batch job 11985239
# Submitted job for NP_T-0290
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0291/slurm/slurm_NP_T-0291.laz.sh
# Submitted batch job 11985246
# Submitted job for NP_T-0291
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0292/slurm/slurm_NP_T-0292.laz.sh
# Submitted batch job 11985252
# Submitted job for NP_T-0292
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0293/slurm/slurm_NP_T-0293.laz.sh
# Submitted batch job 11985261
# Submitted job for NP_T-0293
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0294/slurm/slurm_NP_T-0294.laz.sh
# Submitted batch job 11985270
# Submitted job for NP_T-0294
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0295/slurm/slurm_NP_T-0295.laz.sh
# Submitted batch job 11985276
# Submitted job for NP_T-0295
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0296/slurm/slurm_NP_T-0296.laz.sh
# Submitted batch job 11985279
# Submitted job for NP_T-0296
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0297/slurm/slurm_NP_T-0297.laz.sh
# Submitted batch job 11985285
# Submitted job for NP_T-0297
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0298/slurm/slurm_NP_T-0298.laz.sh
# Submitted job for NP_T-0298
# Submitted batch job 11985290
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0299/slurm/slurm_NP_T-0299.laz.sh
# Submitted batch job 11985309
# Submitted job for NP_T-0299
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0300/slurm/slurm_NP_T-0300.laz.sh
# Submitted batch job 11985327
# Submitted job for NP_T-0300
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0301/slurm/slurm_NP_T-0301.laz.sh
# Submitted batch job 11985331
# Submitted job for NP_T-0301
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0302/slurm/slurm_NP_T-0302.laz.sh
# Submitted batch job 11985334
# Submitted job for NP_T-0302
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0303/slurm/slurm_NP_T-0303.laz.sh
# Submitted batch job 11985337
# Submitted job for NP_T-0303
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0304/slurm/slurm_NP_T-0304.laz.sh
# Submitted batch job 11985341
# Submitted job for NP_T-0304
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0305/slurm/slurm_NP_T-0305.laz.sh
# Submitted batch job 11985344
# Submitted job for NP_T-0305
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0306/slurm/slurm_NP_T-0306.laz.sh
# Submitted batch job 11985347
# Submitted job for NP_T-0306
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0307/slurm/slurm_NP_T-0307.laz.sh
# Submitted batch job 11985358
# Submitted job for NP_T-0307
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0308/slurm/slurm_NP_T-0308.laz.sh
# Submitted batch job 11985364
# Submitted job for NP_T-0308
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0309/slurm/slurm_NP_T-0309.laz.sh
# Submitted batch job 11985367
# Submitted job for NP_T-0309
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0310/slurm/slurm_NP_T-0310.laz.sh
# Submitted batch job 11985369
# Submitted job for NP_T-0310
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0311/slurm/slurm_NP_T-0311.laz.sh
# Submitted batch job 11985372
# Submitted job for NP_T-0311
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0312/slurm/slurm_NP_T-0312.laz.sh
# Submitted batch job 11985376
# Submitted job for NP_T-0312
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0313/slurm/slurm_NP_T-0313.laz.sh
# Submitted batch job 11985379
# Submitted job for NP_T-0313
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0314/slurm/slurm_NP_T-0314.laz.sh
# Submitted batch job 11985382
# Submitted job for NP_T-0314
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0315/slurm/slurm_NP_T-0315.laz.sh
# Submitted batch job 11985386
# Submitted job for NP_T-0315
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0316/slurm/slurm_NP_T-0316.laz.sh
# Submitted batch job 11985389
# Submitted job for NP_T-0316
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0317/slurm/slurm_NP_T-0317.laz.sh
# Submitted batch job 11985394
# Submitted job for NP_T-0317
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0318/slurm/slurm_NP_T-0318.laz.sh
# Submitted batch job 11985399
# Submitted job for NP_T-0318
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0319/slurm/slurm_NP_T-0319.laz.sh
# Submitted batch job 11985403
# Submitted job for NP_T-0319
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0320/slurm/slurm_NP_T-0320.laz.sh
# Submitted batch job 11985407
# Submitted job for NP_T-0320
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0321/slurm/slurm_NP_T-0321.laz.sh
# Submitted batch job 11985411
# Submitted job for NP_T-0321
# ...
# Submitted job for NP_T-0903
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0904/slurm/slurm_NP_T-0904.laz.sh
# Submitted batch job 11986807
# Submitted job for NP_T-0904
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0905/slurm/slurm_NP_T-0905.laz.sh
# Submitted job for NP_T-0905
# Submitted batch job 11986808
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0906/slurm/slurm_NP_T-0906.laz.sh
# Submitted batch job 11986809
# Submitted job for NP_T-0906
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0908/slurm/slurm_NP_T-0908.laz.sh
# Submitted batch job 11986810
# Submitted job for NP_T-0908
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0909/slurm/slurm_NP_T-0909.laz.sh
# Submitted batch job 11986811
# Submitted job for NP_T-0909
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0912/slurm/slurm_NP_T-0912.laz.sh
# Submitted batch job 11986816
# Submitted job for NP_T-0912
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0913/slurm/slurm_NP_T-0913.laz.sh
# Submitted batch job 11986818
# Submitted job for NP_T-0913
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0914/slurm/slurm_NP_T-0914.laz.sh
# Submitted batch job 11986821
# Submitted job for NP_T-0914
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0915/slurm/slurm_NP_T-0915.laz.sh
# Submitted batch job 11986826
# Submitted job for NP_T-0915
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0916/slurm/slurm_NP_T-0916.laz.sh
# Submitted batch job 11986830
# Submitted job for NP_T-0916
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0917/slurm/slurm_NP_T-0917.laz.sh
# Submitted batch job 11986832
# Submitted job for NP_T-0917
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0918/slurm/slurm_NP_T-0918.laz.sh
# Submitted batch job 11986833
# Submitted job for NP_T-0918
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0919/slurm/slurm_NP_T-0919.laz.sh
# Submitted batch job 11986834
# Submitted job for NP_T-0919
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0921/slurm/slurm_NP_T-0921.laz.sh
# Submitted batch job 11986835
# Submitted job for NP_T-0921
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0922/slurm/slurm_NP_T-0922.laz.sh
# Submitted batch job 11986836
# Submitted job for NP_T-0922
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0924/slurm/slurm_NP_T-0924.laz.sh
# Submitted job for NP_T-0924
# Submitted batch job 11986838
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0925/slurm/slurm_NP_T-0925.laz.sh
# Submitted batch job 11986839
# Submitted job for NP_T-0925
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0932/slurm/slurm_NP_T-0932.laz.sh
# Submitted job for NP_T-0932Submitted batch job 11986840
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0934/slurm/slurm_NP_T-0934.laz.sh
# Submitted batch job 11986841
# Submitted job for NP_T-0934
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0938/slurm/slurm_NP_T-0938.laz.sh
# Submitted batch job 11986842
# Submitted job for NP_T-0938
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0939/slurm/slurm_NP_T-0939.laz.sh
# Submitted job for NP_T-0939
# Submitted batch job 11986843
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0943/slurm/slurm_NP_T-0943.laz.sh
# Submitted batch job 11986844
# Submitted job for NP_T-0943
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0954/slurm/slurm_NP_T-0954.laz.sh
# Submitted batch job 11986845
# Submitted job for NP_T-0954
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0956/slurm/slurm_NP_T-0956.laz.sh
# Submitted batch job 11986846
# Submitted job for NP_T-0956
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0958/slurm/slurm_NP_T-0958.laz.sh
# Submitted batch job 11986852
# Submitted job for NP_T-0958
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0959/slurm/slurm_NP_T-0959.laz.sh
# Submitted batch job 11986855
# Submitted job for NP_T-0959
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0961/slurm/slurm_NP_T-0961.laz.sh
# Submitted batch job 11986856
# Submitted job for NP_T-0961
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0965/slurm/slurm_NP_T-0965.laz.sh
# Submitted job for NP_T-0965
# Submitted batch job 11986863
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0967/slurm/slurm_NP_T-0967.laz.sh
# Submitted batch job 11986864
# Submitted job for NP_T-0967
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0972/slurm/slurm_NP_T-0972.laz.sh
# Submitted job for NP_T-0972Submitted batch job 11986869
#
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0976/slurm/slurm_NP_T-0976.laz.sh
# Submitted batch job 11986882
# Submitted job for NP_T-0976
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0980/slurm/slurm_NP_T-0980.laz.sh
# Submitted batch job 11986887
# Submitted job for NP_T-0980
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0986/slurm/slurm_NP_T-0986.laz.sh
# Submitted batch job 11986888
# Submitted job for NP_T-0986
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0987/slurm/slurm_NP_T-0987.laz.sh
# Submitted batch job 11986889
# Submitted job for NP_T-0987
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0989/slurm/slurm_NP_T-0989.laz.sh
# Submitted batch job 11986897
# Submitted job for NP_T-0989
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0992/slurm/slurm_NP_T-0992.laz.sh
# Submitted batch job 11986911
# Submitted job for NP_T-0992
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0995/slurm/slurm_NP_T-0995.laz.sh
# Submitted batch job 11986913
# Submitted job for NP_T-0995
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0997/slurm/slurm_NP_T-0997.laz.sh
# Submitted batch job 11986918
# Submitted job for NP_T-0997
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-0999/slurm/slurm_NP_T-0999.laz.sh
# Submitted batch job 11986921
# Submitted job for NP_T-0999
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1001/slurm/slurm_NP_T-1001.laz.sh
# Submitted batch job 11986922
# Submitted job for NP_T-1001
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1002/slurm/slurm_NP_T-1002.laz.sh
# Submitted batch job 11986923
# Submitted job for NP_T-1002
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1003/slurm/slurm_NP_T-1003.laz.sh
# Submitted batch job 11986924
# Submitted job for NP_T-1003
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1004/slurm/slurm_NP_T-1004.laz.sh
# Submitted batch job 11986925
# Submitted job for NP_T-1004
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1005/slurm/slurm_NP_T-1005.laz.sh
# Submitted batch job 11986927
# Submitted job for NP_T-1005
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1006/slurm/slurm_NP_T-1006.laz.sh
# Submitted batch job 11986931
# Submitted job for NP_T-1006
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1007/slurm/slurm_NP_T-1007.laz.sh
# Submitted batch job 11986932
# Submitted job for NP_T-1007
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1010/slurm/slurm_NP_T-1010.laz.sh
# Submitted batch job 11986938
# Submitted job for NP_T-1010
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1011/slurm/slurm_NP_T-1011.laz.sh
# Submitted job for NP_T-1011
# Submitted batch job 11986940
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1012/slurm/slurm_NP_T-1012.laz.sh
# Submitted batch job 11986941
# Submitted job for NP_T-1012
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1013/slurm/slurm_NP_T-1013.laz.sh
# Submitted batch job 11986942
# Submitted job for NP_T-1013
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1014/slurm/slurm_NP_T-1014.laz.sh
# Submitted batch job 11986943
# Submitted job for NP_T-1014
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016/slurm/slurm_NP_T-1016.laz.sh
# Submitted batch job 11986944
# Submitted job for NP_T-1016
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016/slurm/slurm_NP_T-1016.laz.sh
# Submitted batch job 11986949
# Submitted job for NP_T-1016
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016/slurm/slurm_NP_T-1016.laz.sh
# Submitted batch job 11986952
# Submitted job for NP_T-1016
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016/slurm/slurm_NP_T-1016.laz.sh
# Submitted job for NP_T-1016
# Submitted batch job 11986956
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016/slurm/slurm_NP_T-1016.laz.sh
# Submitted batch job 11986958
# Submitted job for NP_T-1016
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016/slurm/slurm_NP_T-1016.laz.sh
# Submitted batch job 11986959
# Submitted job for NP_T-1016
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016/slurm/slurm_NP_T-1016.laz.sh
# Submitted batch job 11986960
# Submitted job for NP_T-1016
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016/slurm/slurm_NP_T-1016.laz.sh
# Submitted batch job 11986961
# Submitted job for NP_T-1016
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016/slurm/slurm_NP_T-1016.laz.sh
# Submitted batch job 11986962
# Submitted job for NP_T-1016
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016_001/slurm/slurm_NP_T-1016_001.laz.sh
# Submitted batch job 11986963
# Submitted job for NP_T-1016_001
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016_002/slurm/slurm_NP_T-1016_002.laz.sh
# Submitted batch job 11986964
# Submitted job for NP_T-1016_002
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016_003/slurm/slurm_NP_T-1016_003.laz.sh
# Submitted batch job 11986965
# Submitted job for NP_T-1016_003
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016_004/slurm/slurm_NP_T-1016_004.laz.sh
# Submitted batch job 11986967
# Submitted job for NP_T-1016_004
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016_005/slurm/slurm_NP_T-1016_005.laz.sh
# Submitted batch job 11986975
# Submitted job for NP_T-1016_005
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016_006/slurm/slurm_NP_T-1016_006.laz.sh
# Submitted batch job 11986976
# Submitted job for NP_T-1016_006
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016_007/slurm/slurm_NP_T-1016_007.laz.sh
# Submitted batch job 11986977
# Submitted job for NP_T-1016_007
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016_008/slurm/slurm_NP_T-1016_008.laz.sh
# Submitted batch job 11986978
# Submitted job for NP_T-1016_008
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1016_009/slurm/slurm_NP_T-1016_009.laz.sh
# Submitted batch job 11986979
# Submitted job for NP_T-1016_009
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1021/slurm/slurm_NP_T-1021.laz.sh
# Submitted job for NP_T-1021
# Submitted batch job 11986980
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1022/slurm/slurm_NP_T-1022.laz.sh
# Submitted batch job 11986985
# Submitted job for NP_T-1022
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1023/slurm/slurm_NP_T-1023.laz.sh
# Submitted batch job 11986986
# Submitted job for NP_T-1023
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1024/slurm/slurm_NP_T-1024.laz.sh
# Submitted batch job 11986987
# Submitted job for NP_T-1024
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1025/slurm/slurm_NP_T-1025.laz.sh
# Submitted batch job 11986992
# Submitted job for NP_T-1025
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1026/slurm/slurm_NP_T-1026.laz.sh
# Submitted batch job 11986993
# Submitted job for NP_T-1026
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1027/slurm/slurm_NP_T-1027.laz.sh
# Submitted batch job 11986994
# Submitted job for NP_T-1027
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1028/slurm/slurm_NP_T-1028.laz.sh
# Submitted batch job 11986995
# Submitted job for NP_T-1028
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1029/slurm/slurm_NP_T-1029.laz.sh
# Submitted batch job 11986996
# Submitted job for NP_T-1029
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1030/slurm/slurm_NP_T-1030.laz.sh
# Submitted batch job 11986998
# Submitted job for NP_T-1030
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1031/slurm/slurm_NP_T-1031.laz.sh
# Submitted batch job 11986999
# Submitted job for NP_T-1031
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1032/slurm/slurm_NP_T-1032.laz.sh
# Submitted batch job 11987000
# Submitted job for NP_T-1032
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1033/slurm/slurm_NP_T-1033.laz.sh
# Submitted batch job 11987004
# Submitted job for NP_T-1033
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1034/slurm/slurm_NP_T-1034.laz.sh
# Submitted batch job 11987007
# Submitted job for NP_T-1034
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1040_01/slurm/slurm_NP_T-1040_01.laz.sh
# Submitted batch job 11987009
# Submitted job for NP_T-1040_02
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1040_03/slurm/slurm_NP_T-1040_03.laz.sh
# Submitted batch job 11987052
# Submitted job for NP_T-1040_03
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1040_04/slurm/slurm_NP_T-1040_04.laz.sh
# Submitted batch job 11987053
# Submitted job for NP_T-1040_04
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1040_05/slurm/slurm_NP_T-1040_05.laz.sh
# Submitted batch job 11987056
# Submitted job for NP_T-1040_05
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1040_06/slurm/slurm_NP_T-1040_06.laz.sh
# Submitted batch job 11987057
# Submitted job for NP_T-1040_06
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1040_07/slurm/slurm_NP_T-1040_07.laz.sh
# Submitted job for NP_T-1040_07
# Submitted batch job 11987058
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1040_08/slurm/slurm_NP_T-1040_08.laz.sh
# Submitted batch job 11987059
# Submitted job for NP_T-1040_08
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1040_09/slurm/slurm_NP_T-1040_09.laz.sh
# Submitted batch job 11987060
# Submitted job for NP_T-1040_09
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1041_01/slurm/slurm_NP_T-1041_01.laz.sh
# Submitted batch job 11987069
# Submitted job for NP_T-1041_01
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1041_02/slurm/slurm_NP_T-1041_02.laz.sh
# Submitted batch job 11987070
# Submitted job for NP_T-1041_02
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1041_03/slurm/slurm_NP_T-1041_03.laz.sh
# Submitted batch job 11987074
# Submitted job for NP_T-1041_03
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1041_04/slurm/slurm_NP_T-1041_04.laz.sh
# Submitted batch job 11987075
# Submitted job for NP_T-1041_04
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1041_05/slurm/slurm_NP_T-1041_05.laz.sh
# Submitted batch job 11987078
# Submitted job for NP_T-1041_05
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1041_06/slurm/slurm_NP_T-1041_06.laz.sh
# Submitted batch job 11987079
# Submitted job for NP_T-1041_06
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1041_07/slurm/slurm_NP_T-1041_07.laz.sh
# Submitted batch job 11987082
# Submitted job for NP_T-1041_07
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-1082/slurm/slurm_NP_T-1082.laz.sh
# Submitted batch job 11987085
# Submitted job for NP_T-1082
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-2001/slurm/slurm_NP_T-2001.laz.sh
# Submitted batch job 11987087
# Submitted job for NP_T-2001
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-2002/slurm/slurm_NP_T-2002.laz.sh
# Submitted batch job 11987093
# Submitted job for NP_T-2002
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-2004/slurm/slurm_NP_T-2004.laz.sh
# Submitted batch job 11987095
# Submitted job for NP_T-2004
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-2005/slurm/slurm_NP_T-2005.laz.sh
# Submitted job for NP_T-2005
# Submitted batch job 11987100
# /work/scratch-nopw/forecol/EBA_lidar/laz_EBA_processed/NP_T-2006/slurm/slurm_NP_T-2006.laz.sh
# Submitted job for NP_T-2006
# Submitted batch job 11987101

# %% [markdown]
# ### Metrics: Create slurm job

# %%
unavailable = []
for idx, survey in tqdm(eba_new_meta.iterrows(), total=len(eba_new_meta)):
    
    if survey["path"] is None or pd.isna(survey["path"]):
        continue
    
    if os.getenv("USE_SCRATCH"):
        out_dir = SCRATCH_PATH / "EBA_lidar" / "laz_EBA_processed" / survey["name"]
    else: 
        out_dir = EBALIDAR_PATH / "laz_EBA_processed" / survey["name"]
    
    # The processing job stores its output in the folder grid_metrics.
    # If this folder already exists and is not empty, do not reprocess.
    # TODO: Move this check into slurm_jobcreator.py
    if contains(out_dir, "grid_metrics") and not is_empty(out_dir / "grid_metrics"):
        unavailable.append(survey.name)
        continue
    
    job_file = lidR_gridmetrics_job(# File params
                                    lidar_path=(out_dir / "processed"),
                                    survey_name=survey.name, 
                                    out_dir=out_dir,
                                    # Processing params
                                    metrics = {"point_density": [1],
                                               "pulse_density": [1],
                                               "ground_point_density": [1],
                                               "n_points": [1],
                                               "n_pulses": [1],
                                               "n_ground_points": [1],
                                               "max": [10, 50],
                                               "quantile_0.05": [10, 50],
                                               "quantile_0.1": [10, 50],
                                               "kurtosis": [10, 50],
                                               "mean": [10, 50],
                                               "interquartile_range": [10, 50],
                                               "longo_biomass": [10, 50], 
                                               "canopy_height": [1, 2]

                                    },
                                    buffer = 10,
                                    chunk_size = 0,
                                    as_file = False,

                                    # Queue params
                                    queue="short-serial",
                                    max_time = datetime.time(10, 0, 0),
                                    #expected_time = datetime.time(1, 30, 0),
                                    required_memory_per_node=8000,
                               )
    print(job_file)
    # Submit job
    break
    sbatch(job_file)
    print(f"Submitted job for {survey['name']}")

if len(unavailable) > 0:
    print("Could not find normalized input data for the following {} surveys:".format(len(unavailable)))
    for s in unavailable:
        print(s)
# Out:
#   0%|          | 0/930 [00:00<?, ?it/s]
# #!/bin/bash
# #SBATCH --partition=short-serial
# #SBATCH --time=10:00:00  # Set a timeout for the job in HH:MM:SS
# #SBATCH --mem=8000 # Set the amount of memory for per node in MB.
# #SBATCH --job-name=NP_T-0001_grid_metrics
# #SBATCH --chdir=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/slurm
# #SBATCH --output=slurm_NP_T-0001_metrics-%j.out
# #SBATCH --error=slurm_NP_T-0001_metrics-%j.err
#
#
# # --- TEMPLATE AUTOGENERATED ---
#
#
# echo "==================== Activating conda environment ===================="
# source ~/.bashrc
# conda activate r4_env
#
# echo "==================== Checking R version ===================="
# echo "$(which R)"
# echo "$(R --version)"
#
# echo "==================== Analysing file ===================="
# echo "template generation time: 2021-06-24 13:02:05.482052"
# echo "survey: NP_T-0001"
# echo "path: /gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed"
# echo "metrics: {'point_density': [1], 'pulse_density': [1], 'ground_point_density': [1], 'n_points': [1], 'n_pulses': [1], 'n_ground_points': [1], 'max': [10, 50], 'quantile_0.05': [10, 50], 'quantile_0.1': [10, 50], 'kurtosis': [10, 50], 'mean': [10, 50], 'interquartile_range': [10, 50], 'longo_biomass': [10, 50], 'canopy_height': [1, 2]}"
#
# echo "==================== Executing R script ===================="
#
# # `Canopy height` at grid size `1m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_canopy_height_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --gridsize=1 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # `Canopy height` at grid size `2m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_canopy_height_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --gridsize=2 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `point_density` at grid size `1m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=point_density --gridsize=1 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `pulse_density` at grid size `1m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=pulse_density --gridsize=1 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `ground_point_density` at grid size `1m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=ground_point_density --gridsize=1 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `n_points` at grid size `1m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=n_points --gridsize=1 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `n_pulses` at grid size `1m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=n_pulses --gridsize=1 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `n_ground_points` at grid size `1m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=n_ground_points --gridsize=1 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `max` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=max --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `max` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=max --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `quantile_0.05` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=quantile --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE --quantile=0.05
#
# # Metric `quantile_0.05` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=quantile --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE --quantile=0.05
#
# # Metric `quantile_0.1` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=quantile --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE --quantile=0.1
#
# # Metric `quantile_0.1` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=quantile --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE --quantile=0.1
#
# # Metric `kurtosis` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=kurtosis --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `kurtosis` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=kurtosis --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `mean` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=mean --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `mean` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=mean --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `interquartile_range` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=interquartile_range --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `interquartile_range` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=interquartile_range --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `longo_biomass` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=longo_biomass --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `longo_biomass` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001/processed --metric=longo_biomass --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/EBA_lidar/laz_EBA_processed/NP_T-0001 --buffer=10 --chunk_size=0 --save_prefix=NP_T-0001_ --overwrite=FALSE --check_index=TRUE

# %% [markdown]
# ----------------

# %% [markdown]
# # To be deleted: Expedited processing for relevant files

# %%
relevant = [
    "NP_T-0408.laz",
    "NP_T-0859.laz",
    "NP_T-0145.laz",
    "NP_T-0751.laz",
    "NP_T-2002.laz",
    "NP_T-0416.laz",
    "NP_T-0669.laz",
]

for idx, survey in eba_new_meta.loc[relevant].iterrows():
    
    #if survey["path"] is None or pd.isna(survey["path"]):
    #    continue
    
    out_dir = EBALIDAR_PATH / "laz_EBA_processed" / survey["name"]
    
    job_file = create_lidar_gridmetrics_job(idx, 
                                survey, 
                                out_dir,
                                metrics = {"point_density": [1],
                                           "pulse_density": [1],
                                           "ground_point_density": [1],
                                           "n_points": [1],
                                           "n_pulses": [1],
                                           "n_ground_points": [1],
                                           "max": [10, 50],
                                           "quantile_0.05": [10, 50],
                                           "quantile_0.1": [10, 50],
                                           "kurtosis": [10, 50],
                                           "mean": [10, 50],
                                           "interquartile_range": [10, 50],
                                           "longo_biomass": [10, 50], 
                                           "canopy_height": [1, 2]
                                
                                },
                                buffer = 10,
                                chunk_size = 0,
                                as_file = True,
                                overwrite=False,
                                queue="test",
                                
                               )
    print(job_file)
    break
    # Submit job
    #sbatch(job_file)
    print(f"Submitted job for {survey['name']}")
# Out:
# Submitted job for NP_T-0408
# Submitted job for NP_T-0859
# Submitted job for NP_T-0145
# Submitted job for NP_T-0751
# Submitted job for NP_T-2002
# Submitted job for NP_T-0416
# Submitted job for NP_T-0669

# %%
paisagens_relevant = [
    "JAM_A03_2013_laz",
    "JAM_A02_2013_laz",
    "JAM_A02a_2014_laz",
    "JAM_A02c_2015_LiDAR",
    "SAN_A02_2014_laz",
    
]

for idx, survey in paisagens_surveys.loc[paisagens_relevant][4::].iterrows():
    
    #if survey["path"] is None or pd.isna(survey["path"]):
    #    continue
    
    out_dir = PAISAGENSLIDAR_PATH / "processed" / str(survey["year"]) / survey["name"]
    
    if contains(out_dir, "processed") and not is_empty(out_dir / "processed"):
        pass
    else:
        print(survey["name"], "not available.")
        continue
    
    job_file = lidR_gridmetrics_job(survey, 
                                    out_dir,
                                    metrics = {"n_points": [1],
                                               "n_pulses": [1],
                                               "n_ground_points": [1],
                                               "max": [10, 50],
                                               "quantile_0.05": [10, 50],
                                               "quantile_0.1": [10, 50],
                                               "kurtosis": [10, 50],
                                               "mean": [10, 50],
                                               "interquartile_range": [10, 50],
                                               "longo_biomass": [10, 50], 
                                               "canopy_height": [1]

                                    },
                                    buffer = 10,
                                    chunk_size = 0,
                                    as_file = False,
                                    overwrite=False,
                                    queue="test",
                                    required_memory_per_node=8000,    
                                    max_time = datetime.time(10, 0, 0)
                                   )
    print(job_file)
    break
    # Submit job
    sbatch(job_file)
    print(f"Submitted job for {survey['name']}")
# Out:
# #!/bin/bash
# #SBATCH --partition=test
# #SBATCH --time=10:00:00  # Set a timeout for the job in HH:MM:SS
# #SBATCH --mem=8000 # Set the amount of memory for per node in MB.
# #SBATCH --job-name=SAN_A02_2014_grid_metrics
# #SBATCH --chdir=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/slurm
# #SBATCH --output=slurm_SAN_A02_2014_metrics-%j.out
# #SBATCH --error=slurm_SAN_A02_2014_metrics-%j.err
#
#
# # --- TEMPLATE AUTOGENERATED ---
#
#
# echo "==================== Activating conda environment ===================="
# source ~/.bashrc
# conda activate r4_env
#
# echo "==================== Checking R version ===================="
# echo "$(which R)"
# echo "$(R --version)"
#
# echo "==================== Analysing file ===================="
# echo "template generation time: 2021-06-24 18:16:43.778255"
# echo "survey: SAN_A02_2014"
# echo "path: /gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed"
# echo "metrics: {'n_points': [1], 'n_pulses': [1], 'n_ground_points': [1], 'max': [10, 50], 'quantile_0.05': [10, 50], 'quantile_0.1': [10, 50], 'kurtosis': [10, 50], 'mean': [10, 50], 'interquartile_range': [10, 50], 'longo_biomass': [10, 50], 'canopy_height': [1]}"
#
# echo "==================== Executing R script ===================="
#
# # `Canopy height` at grid size `1m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_canopy_height_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --gridsize=1 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `n_points` at grid size `1m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=n_points --gridsize=1 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `n_pulses` at grid size `1m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=n_pulses --gridsize=1 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `n_ground_points` at grid size `1m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=n_ground_points --gridsize=1 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `max` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=max --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `max` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=max --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `quantile_0.05` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=quantile --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE --quantile=0.05
#
# # Metric `quantile_0.05` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=quantile --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE --quantile=0.05
#
# # Metric `quantile_0.1` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=quantile --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE --quantile=0.1
#
# # Metric `quantile_0.1` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=quantile --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE --quantile=0.1
#
# # Metric `kurtosis` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=kurtosis --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `kurtosis` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=kurtosis --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `mean` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=mean --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `mean` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=mean --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `interquartile_range` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=interquartile_range --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `interquartile_range` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=interquartile_range --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `longo_biomass` at grid size `10m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=longo_biomass --gridsize=10 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE
#
# # Metric `longo_biomass` at grid size `50m`
# Rscript --verbose --no-save /home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R --lidar_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014/processed --metric=longo_biomass --gridsize=50 --save_path=/gws/nopw/j04/forecol/data/Paisagenslidar/processed/2014/SAN_A02_2014 --buffer=10 --chunk_size=0 --save_prefix=SAN_A02_2014_ --overwrite=FALSE --check_index=TRUE

# %% [markdown]
# ----

# %% [markdown]
# # Legacy

# %%
def create_lidar_processing_job(idx, 
                                survey, 
                                r_file,
                                out_dir,
                                buffer = 50,
                                chunk_size = 0,
                                filter_quantile = 0.95, 
                                filter_sensitivity = 1.1,
                                filter_gridsize = 10,
                                compress_intermediates = True,
                                save_intermediates = True,
                                perform_check = True,
                                as_file = True,
                                **kwargs
                               ):
    # Path for lidar data
    lidar_path = pathlib.Path(survey["path"])
    assert lidar_path.exists()
    
    # Set up save prefix
    save_prefix = survey["name"] + "_"

    # Create working directory path
    slurm_dir = out_dir / "slurm"
    slurm_dir.mkdir(parents=True, exist_ok=True)

    # Create sbatch header
    header = sbatch_header(
                  job_name = idx + "-->" + survey["name"],
                  working_directory=slurm_dir,
                  output_file_pattern=f"slurm_{survey['name']}-%j.out",
                  error_file_pattern=f"slurm_{survey['name']}-%j.err",
                  **kwargs)

    body = seperator("Activating conda environment")
    body += "source ~/.bashrc\n"
    body += "conda activate r4_env\n"
    body += seperator("Checking R version")
    body += echo("$(which R)")
    #body += "echo $(which R)\n"
    body += echo("$(R --version)")
    body += seperator("Analysing file")
    body += echo(f"template generation time: {datetime.datetime.now()}")
    body += echo(f"survey: {survey['name']}")
    body += echo(f"path: {lidar_path}")
    body += seperator("Executing R script")
    body += (f"Rscript --verbose --no-save {r_file}" 
             f" --lidar_path={lidar_path}" 
             f" --save_path={out_dir}"
             f" --buffer={buffer}"
             f" --chunk_size={chunk_size}"
             f" --filter_quantile={filter_quantile}"
             f" --filter_sensitivity={filter_sensitivity}"
             f" --filter_gridsize={filter_gridsize}"
             f" --save_prefix={save_prefix}"
             f" --perform_check={'TRUE' if perform_check else 'FALSE'}"
             f" --save_intermediates={'TRUE' if save_intermediates else 'FALSE'}"
             f" --compress_intermediates={'TRUE' if compress_intermediates else 'FALSE'}"
            )

    if as_file:
        job_file = slurm_dir / f"slurm_{survey['name']}.sh"
        with open(job_file, "w") as file:
            file.write(header + body)
        return job_file
    else: 
        return header+body

# %%
ALLOWED_METRICS = ("point_density", "pulse_density", "ground_point_density",
                   "n_points", "n_pulses", "n_ground_points",
                   "max", "standard_dev", "mask", "mean", "kurtosis", 
                   "interquartile_range", "quantile", "longo_biomass")

r_gridmetrics_file = "/home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_gridmetrics_script.R"
r_canopy_height_file = "/home/users/svm/Code/gedi_biomass_mapping/src/processing/lidar_canopy_height_script.R"

def create_lidar_gridmetrics_job(idx, 
                                survey, 
                                out_dir,
                                metrics,
                                buffer = 10,
                                chunk_size = 0,
                                save_prefix="",
                                check_index=True,
                                overwrite=False,
                                as_file = False,
                                **kwargs
                               ):
    # Path for lidar data
    lidar_path = pathlib.Path(out_dir / "processed")
    assert lidar_path.exists()
    
    # Set up save prefix
    save_prefix = survey["name"] + "_"

    # Create working directory path
    slurm_dir = out_dir / "slurm"
    slurm_dir.mkdir(parents=True, exist_ok=True)
    grid_metrics_dir = out_dir / "grid_metrics"
    grid_metrics_dir.mkdir(parents=True, exist_ok=True)

    # Create sbatch header
    header = sbatch_header(
                  job_name = survey["name"] + "_grid_metrics",
                  working_directory=slurm_dir,
                  output_file_pattern=f"slurm_{survey['name']}_metrics-%j.out",
                  error_file_pattern=f"slurm_{survey['name']}_metrics-%j.err",
                  **kwargs)

    body = seperator("Activating conda environment")
    body += "source ~/.bashrc\n"
    body += "conda activate r4_env\n"
    body += seperator("Checking R version")
    body += echo("$(which R)")
    body += echo("$(R --version)")
    body += seperator("Analysing file")
    body += echo(f"template generation time: {datetime.datetime.now()}")
    body += echo(f"survey: {survey['name']}")
    body += echo(f"path: {lidar_path}")
    body += echo(f"metrics: {metrics}")
    body += seperator("Executing R script")
    
    if "canopy_height" in metrics.keys():
        for gridsize in metrics.pop("canopy_height"):
            body += f"\n# `Canopy height` at grid size `{gridsize}m`\n"
            body += (f"Rscript --verbose --no-save {r_canopy_height_file}" 
                     f" --lidar_path={lidar_path}"
                     f" --gridsize={gridsize}" 
                     f" --save_path={out_dir}"
                     f" --buffer={buffer}"
                     f" --chunk_size={chunk_size}"
                     f" --save_prefix={save_prefix}"
                     f" --overwrite={'TRUE' if overwrite else 'FALSE'}"
                     f" --check_index={'TRUE' if check_index else 'FALSE'}"
                     "\n"
                    )
    
    for metric in metrics.keys():
        assert metric in ALLOWED_METRICS or "quantile_" in metric, f"{metric} not allowed."
        for gridsize in metrics[metric]:
            body += f"\n# Metric `{metric}` at grid size `{gridsize}m`\n"
            body += (f"Rscript --verbose --no-save {r_gridmetrics_file}" 
                     f" --lidar_path={lidar_path}" 
                     f" --metric={metric if 'quantile' not in metric else 'quantile'}"
                     f" --gridsize={gridsize}" 
                     f" --save_path={out_dir}"
                     f" --buffer={buffer}"
                     f" --chunk_size={chunk_size}"
                     f" --save_prefix={save_prefix}"
                     f" --overwrite={'TRUE' if overwrite else 'FALSE'}"
                     f" --check_index={'TRUE' if check_index else 'FALSE'}"
                     f"{' --quantile='+str(metric.split('_')[-1]) if 'quantile' in metric else ''}"
                     "\n"
                    )

    if as_file:
        job_file = slurm_dir / f"slurm_{survey['name']}_grid_metrics.sh"
        with open(job_file, "w") as file:
            file.write(header + body)
        return job_file
    else: 
        return header+body
